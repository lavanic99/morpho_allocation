# %% [markdown]
# # USDe Morpho Benchmarks and Reallocation
#
# In this Jupyter notebook, we will automate the process of analyzing and reallocating USDe liquidity within Morpho's financial pools.
#
# Our primary focus will lie in assessing the current allocation of USDe, the utilization rates, borrowing rates, optimal rates, and capped rates across different liquidity pools distinguished by their Loan-to-Value (LTV) ratios. We aim to ensure that pool allocations are optimized both for the stable functioning of the overall market and for better returns for liquidity providers and borrowers.
#
# 1. **Data Analysis**: We will start by performing a data analysis on the current status of various USDe pools. This will include processing important metrics such as total supply, borrow rates, and optimal rates to identify pools that may require attention or reallocation.
#
# 2. **Manual Reallocation Criteria**: Based on the analysis, we'll assess the necessity for manual reallocations in accordance with established criteria for active and inactive pools, including factors like minimum balances, maximum utilization, and the safety margin for withdrawing portions of the allocated USDe supply.

# %%
import pandas as pd
import numpy as np
import datetime
import math
import json
from data_manipulation import *
from api import *

pd.set_option('display.max_columns', None)

# %% [markdown]
# ## Manual Reallocation Analysis
#
# Defined Pools we look at for allocation and necessary values

# %%
pool_keys = [
    'USDe 94.50%',
    'USDe 91.50%',
    'USDe 86%',
    'USDe 77%',
    'sUSDe 94.50%',
    'sUSDe 91.50%',
    'sUSDe 86%',
    'sUSDe 77%',
    'PT-sUSDe-24Oct2024 86%',
    'PT-sUSDe-26Dec2024 91.5%',
    'PT-sUSDe-27Mar2025 91.5%',
    'PT-USDe-27Mar2025 91.5%',
    'PT-sUSDe-29May2025 91.5%'
]
idle_key = [
    'Idle',
]
idle_col = [
    'LLTV',
    'Total Supply', 
    'Maker Allocation',     
    'Utilization', 
    'Borrow Rate',              
]
columns_ordered = [
    'Status', 
    'LLTV',
    'Total Supply', 
    'Maker Allocation', 
    'Utilization', 
    'Borrow Rate',
    'Supply Cap',
    'Total Borrow', 
    'Maker Borrow', 
    'Optimal Rate', 
    'Capped Borrow Rate', 
    'SSR',
    'Fixed Spread',
    'Fixed Spread Rate Value',
    'Fixed Slope per 100M',
    'Fixed Slope',
    'Proportional Spread',
    'Proportional Spread Rate Value',
    'Proportional Spread Fixed Value',
    'Proportional Slope per 100M',
    'Proportional Slope',
    'Proportional Slope Fixed Value',
    'Low Target Threshold',
    'High Target Threshold',
    'Target Borrow Rate',
    'Min Borrow Rate',
    'Max Borrow Rate',
    'Utilization Where Rate Equal to SSR',
    'SSR Adjustment',
    'Total Supply After SSR Adjustment',
    'Maker Supply After SSR Adjustment',
    'Utilization After SSR Adjustment',
    'Inactive Withdrawal',
    'Utilization Where Rate Equal To Min Target',
    'Active Withdrawal',
    'Utilization Where Rate Equal To Max Target',
    'Active Deposits',
    'Manual Adjustment',
    'Total Change',
    'Final Allocation',
    'Final Supply',
    'Final Utilization',
    'Final Borrow Rate',
    'Final Capped Rate',
    'Maker Borrow at Old Utilization',
    'Borrow Rate Change',                   
]

pools_df = pd.DataFrame(index=pool_keys, columns=columns_ordered)
idle_df = pd.DataFrame(index=idle_key, columns=idle_col)
pools_df
# Out:
#                          Status LLTV Total Supply Maker Allocation  \
# USDe 94.50%                 NaN  NaN          NaN              NaN
# USDe 91.50%                 NaN  NaN          NaN              NaN
# USDe 86%                    NaN  NaN          NaN              NaN
# USDe 77%                    NaN  NaN          NaN              NaN
# sUSDe 94.50%                NaN  NaN          NaN              NaN
# sUSDe 91.50%                NaN  NaN          NaN              NaN
# sUSDe 86%                   NaN  NaN          NaN              NaN
# sUSDe 77%                   NaN  NaN          NaN              NaN
# PT-sUSDe-24Oct2024 86%      NaN  NaN          NaN              NaN
# PT-sUSDe-26Dec2024 91.5%    NaN  NaN          NaN              NaN
# PT-sUSDe-27Mar2025 91.5%    NaN  NaN          NaN              NaN
# PT-USDe-27Mar2025 91.5%     NaN  NaN          NaN              NaN
# PT-sUSDe-29May2025 91.5%    NaN  NaN          NaN              NaN
#
#                          Utilization Borrow Rate Supply Cap Total Borrow  \
# USDe 94.50%                      NaN         NaN        NaN          NaN
# USDe 91.50%                      NaN         NaN        NaN          NaN
# USDe 86%                         NaN         NaN        NaN          NaN
# USDe 77%                         NaN         NaN        NaN          NaN
# sUSDe 94.50%                     NaN         NaN        NaN          NaN
# sUSDe 91.50%                     NaN         NaN        NaN          NaN
# sUSDe 86%                        NaN         NaN        NaN          NaN
# sUSDe 77%                        NaN         NaN        NaN          NaN
# PT-sUSDe-24Oct2024 86%           NaN         NaN        NaN          NaN
# PT-sUSDe-26Dec2024 91.5%         NaN         NaN        NaN          NaN
# PT-sUSDe-27Mar2025 91.5%         NaN         NaN        NaN          NaN
# PT-USDe-27Mar2025 91.5%          NaN         NaN        NaN          NaN
# PT-sUSDe-29May2025 91.5%         NaN         NaN        NaN          NaN
#
#                          Maker Borrow Optimal Rate Capped Borrow Rate  SSR  \
# USDe 94.50%                       NaN          NaN                NaN  NaN
# USDe 91.50%                       NaN          NaN                NaN  NaN
# USDe 86%                          NaN          NaN                NaN  NaN
# USDe 77%                          NaN          NaN                NaN  NaN
# sUSDe 94.50%                      NaN          NaN                NaN  NaN
# sUSDe 91.50%                      NaN          NaN                NaN  NaN
# sUSDe 86%                         NaN          NaN                NaN  NaN
# sUSDe 77%                         NaN          NaN                NaN  NaN
# PT-sUSDe-24Oct2024 86%            NaN          NaN                NaN  NaN
# PT-sUSDe-26Dec2024 91.5%          NaN          NaN                NaN  NaN
# PT-sUSDe-27Mar2025 91.5%          NaN          NaN                NaN  NaN
# PT-USDe-27Mar2025 91.5%           NaN          NaN                NaN  NaN
# PT-sUSDe-29May2025 91.5%          NaN          NaN                NaN  NaN
#
#                          Fixed Spread Fixed Spread Rate Value  \
# USDe 94.50%                       NaN                     NaN
# USDe 91.50%                       NaN                     NaN
# USDe 86%                          NaN                     NaN
# USDe 77%                          NaN                     NaN
# sUSDe 94.50%                      NaN                     NaN
# sUSDe 91.50%                      NaN                     NaN
# sUSDe 86%                         NaN                     NaN
# sUSDe 77%                         NaN                     NaN
# PT-sUSDe-24Oct2024 86%            NaN                     NaN
# PT-sUSDe-26Dec2024 91.5%          NaN                     NaN
# PT-sUSDe-27Mar2025 91.5%          NaN                     NaN
# PT-USDe-27Mar2025 91.5%           NaN                     NaN
# PT-sUSDe-29May2025 91.5%          NaN                     NaN
#
#                          Fixed Slope per 100M Fixed Slope Proportional Spread  \
# USDe 94.50%                               NaN         NaN                 NaN
# USDe 91.50%                               NaN         NaN                 NaN
# USDe 86%                                  NaN         NaN                 NaN
# USDe 77%                                  NaN         NaN                 NaN
# sUSDe 94.50%                              NaN         NaN                 NaN
# sUSDe 91.50%                              NaN         NaN                 NaN
# sUSDe 86%                                 NaN         NaN                 NaN
# sUSDe 77%                                 NaN         NaN                 NaN
# PT-sUSDe-24Oct2024 86%                    NaN         NaN                 NaN
# PT-sUSDe-26Dec2024 91.5%                  NaN         NaN                 NaN
# PT-sUSDe-27Mar2025 91.5%                  NaN         NaN                 NaN
# PT-USDe-27Mar2025 91.5%                   NaN         NaN                 NaN
# PT-sUSDe-29May2025 91.5%                  NaN         NaN                 NaN
#
#                          Proportional Spread Rate Value  \
# USDe 94.50%                                         NaN
# USDe 91.50%                                         NaN
# USDe 86%                                            NaN
# USDe 77%                                            NaN
# sUSDe 94.50%                                        NaN
# sUSDe 91.50%                                        NaN
# sUSDe 86%                                           NaN
# sUSDe 77%                                           NaN
# PT-sUSDe-24Oct2024 86%                              NaN
# PT-sUSDe-26Dec2024 91.5%                            NaN
# PT-sUSDe-27Mar2025 91.5%                            NaN
# PT-USDe-27Mar2025 91.5%                             NaN
# PT-sUSDe-29May2025 91.5%                            NaN
#
#                          Proportional Spread Fixed Value  \
# USDe 94.50%                                          NaN
# USDe 91.50%                                          NaN
# USDe 86%                                             NaN
# USDe 77%                                             NaN
# sUSDe 94.50%                                         NaN
# sUSDe 91.50%                                         NaN
# sUSDe 86%                                            NaN
# sUSDe 77%                                            NaN
# PT-sUSDe-24Oct2024 86%                               NaN
# PT-sUSDe-26Dec2024 91.5%                             NaN
# PT-sUSDe-27Mar2025 91.5%                             NaN
# PT-USDe-27Mar2025 91.5%                              NaN
# PT-sUSDe-29May2025 91.5%                             NaN
#
#                          Proportional Slope per 100M Proportional Slope  \
# USDe 94.50%                                      NaN                NaN
# USDe 91.50%                                      NaN                NaN
# USDe 86%                                         NaN                NaN
# USDe 77%                                         NaN                NaN
# sUSDe 94.50%                                     NaN                NaN
# sUSDe 91.50%                                     NaN                NaN
# sUSDe 86%                                        NaN                NaN
# sUSDe 77%                                        NaN                NaN
# PT-sUSDe-24Oct2024 86%                           NaN                NaN
# PT-sUSDe-26Dec2024 91.5%                         NaN                NaN
# PT-sUSDe-27Mar2025 91.5%                         NaN                NaN
# PT-USDe-27Mar2025 91.5%                          NaN                NaN
# PT-sUSDe-29May2025 91.5%                         NaN                NaN
#
#                          Proportional Slope Fixed Value Low Target Threshold  \
# USDe 94.50%                                         NaN                  NaN
# USDe 91.50%                                         NaN                  NaN
# USDe 86%                                            NaN                  NaN
# USDe 77%                                            NaN                  NaN
# sUSDe 94.50%                                        NaN                  NaN
# sUSDe 91.50%                                        NaN                  NaN
# sUSDe 86%                                           NaN                  NaN
# sUSDe 77%                                           NaN                  NaN
# PT-sUSDe-24Oct2024 86%                              NaN                  NaN
# PT-sUSDe-26Dec2024 91.5%                            NaN                  NaN
# PT-sUSDe-27Mar2025 91.5%                            NaN                  NaN
# PT-USDe-27Mar2025 91.5%                             NaN                  NaN
# PT-sUSDe-29May2025 91.5%                            NaN                  NaN
#
#                          High Target Threshold Target Borrow Rate  \
# USDe 94.50%                                NaN                NaN
# USDe 91.50%                                NaN                NaN
# USDe 86%                                   NaN                NaN
# USDe 77%                                   NaN                NaN
# sUSDe 94.50%                               NaN                NaN
# sUSDe 91.50%                               NaN                NaN
# sUSDe 86%                                  NaN                NaN
# sUSDe 77%                                  NaN                NaN
# PT-sUSDe-24Oct2024 86%                     NaN                NaN
# PT-sUSDe-26Dec2024 91.5%                   NaN                NaN
# PT-sUSDe-27Mar2025 91.5%                   NaN                NaN
# PT-USDe-27Mar2025 91.5%                    NaN                NaN
# PT-sUSDe-29May2025 91.5%                   NaN                NaN
#
#                          Min Borrow Rate Max Borrow Rate  \
# USDe 94.50%                          NaN             NaN
# USDe 91.50%                          NaN             NaN
# USDe 86%                             NaN             NaN
# USDe 77%                             NaN             NaN
# sUSDe 94.50%                         NaN             NaN
# sUSDe 91.50%                         NaN             NaN
# sUSDe 86%                            NaN             NaN
# sUSDe 77%                            NaN             NaN
# PT-sUSDe-24Oct2024 86%               NaN             NaN
# PT-sUSDe-26Dec2024 91.5%             NaN             NaN
# PT-sUSDe-27Mar2025 91.5%             NaN             NaN
# PT-USDe-27Mar2025 91.5%              NaN             NaN
# PT-sUSDe-29May2025 91.5%             NaN             NaN
#
#                          Utilization Where Rate Equal to SSR SSR Adjustment  \
# USDe 94.50%                                              NaN            NaN
# USDe 91.50%                                              NaN            NaN
# USDe 86%                                                 NaN            NaN
# USDe 77%                                                 NaN            NaN
# sUSDe 94.50%                                             NaN            NaN
# sUSDe 91.50%                                             NaN            NaN
# sUSDe 86%                                                NaN            NaN
# sUSDe 77%                                                NaN            NaN
# PT-sUSDe-24Oct2024 86%                                   NaN            NaN
# PT-sUSDe-26Dec2024 91.5%                                 NaN            NaN
# PT-sUSDe-27Mar2025 91.5%                                 NaN            NaN
# PT-USDe-27Mar2025 91.5%                                  NaN            NaN
# PT-sUSDe-29May2025 91.5%                                 NaN            NaN
#
#                          Total Supply After SSR Adjustment  \
# USDe 94.50%                                            NaN
# USDe 91.50%                                            NaN
# USDe 86%                                               NaN
# USDe 77%                                               NaN
# sUSDe 94.50%                                           NaN
# sUSDe 91.50%                                           NaN
# sUSDe 86%                                              NaN
# sUSDe 77%                                              NaN
# PT-sUSDe-24Oct2024 86%                                 NaN
# PT-sUSDe-26Dec2024 91.5%                               NaN
# PT-sUSDe-27Mar2025 91.5%                               NaN
# PT-USDe-27Mar2025 91.5%                                NaN
# PT-sUSDe-29May2025 91.5%                               NaN
#
#                          Maker Supply After SSR Adjustment  \
# USDe 94.50%                                            NaN
# USDe 91.50%                                            NaN
# USDe 86%                                               NaN
# USDe 77%                                               NaN
# sUSDe 94.50%                                           NaN
# sUSDe 91.50%                                           NaN
# sUSDe 86%                                              NaN
# sUSDe 77%                                              NaN
# PT-sUSDe-24Oct2024 86%                                 NaN
# PT-sUSDe-26Dec2024 91.5%                               NaN
# PT-sUSDe-27Mar2025 91.5%                               NaN
# PT-USDe-27Mar2025 91.5%                                NaN
# PT-sUSDe-29May2025 91.5%                               NaN
#
#                          Utilization After SSR Adjustment Inactive Withdrawal  \
# USDe 94.50%                                           NaN                 NaN
# USDe 91.50%                                           NaN                 NaN
# USDe 86%                                              NaN                 NaN
# USDe 77%                                              NaN                 NaN
# sUSDe 94.50%                                          NaN                 NaN
# sUSDe 91.50%                                          NaN                 NaN
# sUSDe 86%                                             NaN                 NaN
# sUSDe 77%                                             NaN                 NaN
# PT-sUSDe-24Oct2024 86%                                NaN                 NaN
# PT-sUSDe-26Dec2024 91.5%                              NaN                 NaN
# PT-sUSDe-27Mar2025 91.5%                              NaN                 NaN
# PT-USDe-27Mar2025 91.5%                               NaN                 NaN
# PT-sUSDe-29May2025 91.5%                              NaN                 NaN
#
#                          Utilization Where Rate Equal To Min Target  \
# USDe 94.50%                                                     NaN
# USDe 91.50%                                                     NaN
# USDe 86%                                                        NaN
# USDe 77%                                                        NaN
# sUSDe 94.50%                                                    NaN
# sUSDe 91.50%                                                    NaN
# sUSDe 86%                                                       NaN
# sUSDe 77%                                                       NaN
# PT-sUSDe-24Oct2024 86%                                          NaN
# PT-sUSDe-26Dec2024 91.5%                                        NaN
# PT-sUSDe-27Mar2025 91.5%                                        NaN
# PT-USDe-27Mar2025 91.5%                                         NaN
# PT-sUSDe-29May2025 91.5%                                        NaN
#
#                          Active Withdrawal  \
# USDe 94.50%                            NaN
# USDe 91.50%                            NaN
# USDe 86%                               NaN
# USDe 77%                               NaN
# sUSDe 94.50%                           NaN
# sUSDe 91.50%                           NaN
# sUSDe 86%                              NaN
# sUSDe 77%                              NaN
# PT-sUSDe-24Oct2024 86%                 NaN
# PT-sUSDe-26Dec2024 91.5%               NaN
# PT-sUSDe-27Mar2025 91.5%               NaN
# PT-USDe-27Mar2025 91.5%                NaN
# PT-sUSDe-29May2025 91.5%               NaN
#
#                          Utilization Where Rate Equal To Max Target  \
# USDe 94.50%                                                     NaN
# USDe 91.50%                                                     NaN
# USDe 86%                                                        NaN
# USDe 77%                                                        NaN
# sUSDe 94.50%                                                    NaN
# sUSDe 91.50%                                                    NaN
# sUSDe 86%                                                       NaN
# sUSDe 77%                                                       NaN
# PT-sUSDe-24Oct2024 86%                                          NaN
# PT-sUSDe-26Dec2024 91.5%                                        NaN
# PT-sUSDe-27Mar2025 91.5%                                        NaN
# PT-USDe-27Mar2025 91.5%                                         NaN
# PT-sUSDe-29May2025 91.5%                                        NaN
#
#                          Active Deposits Manual Adjustment Total Change  \
# USDe 94.50%                          NaN               NaN          NaN
# USDe 91.50%                          NaN               NaN          NaN
# USDe 86%                             NaN               NaN          NaN
# USDe 77%                             NaN               NaN          NaN
# sUSDe 94.50%                         NaN               NaN          NaN
# sUSDe 91.50%                         NaN               NaN          NaN
# sUSDe 86%                            NaN               NaN          NaN
# sUSDe 77%                            NaN               NaN          NaN
# PT-sUSDe-24Oct2024 86%               NaN               NaN          NaN
# PT-sUSDe-26Dec2024 91.5%             NaN               NaN          NaN
# PT-sUSDe-27Mar2025 91.5%             NaN               NaN          NaN
# PT-USDe-27Mar2025 91.5%              NaN               NaN          NaN
# PT-sUSDe-29May2025 91.5%             NaN               NaN          NaN
#
#                          Final Allocation Final Supply Final Utilization  \
# USDe 94.50%                           NaN          NaN               NaN
# USDe 91.50%                           NaN          NaN               NaN
# USDe 86%                              NaN          NaN               NaN
# USDe 77%                              NaN          NaN               NaN
# sUSDe 94.50%                          NaN          NaN               NaN
# sUSDe 91.50%                          NaN          NaN               NaN
# sUSDe 86%                             NaN          NaN               NaN
# sUSDe 77%                             NaN          NaN               NaN
# PT-sUSDe-24Oct2024 86%                NaN          NaN               NaN
# PT-sUSDe-26Dec2024 91.5%              NaN          NaN               NaN
# PT-sUSDe-27Mar2025 91.5%              NaN          NaN               NaN
# PT-USDe-27Mar2025 91.5%               NaN          NaN               NaN
# PT-sUSDe-29May2025 91.5%              NaN          NaN               NaN
#
#                          Final Borrow Rate Final Capped Rate  \
# USDe 94.50%                            NaN               NaN
# USDe 91.50%                            NaN               NaN
# USDe 86%                               NaN               NaN
# USDe 77%                               NaN               NaN
# sUSDe 94.50%                           NaN               NaN
# sUSDe 91.50%                           NaN               NaN
# sUSDe 86%                              NaN               NaN
# sUSDe 77%                              NaN               NaN
# PT-sUSDe-24Oct2024 86%                 NaN               NaN
# PT-sUSDe-26Dec2024 91.5%               NaN               NaN
# PT-sUSDe-27Mar2025 91.5%               NaN               NaN
# PT-USDe-27Mar2025 91.5%                NaN               NaN
# PT-sUSDe-29May2025 91.5%               NaN               NaN
#
#                          Maker Borrow at Old Utilization Borrow Rate Change
# USDe 94.50%                                          NaN                NaN
# USDe 91.50%                                          NaN                NaN
# USDe 86%                                             NaN                NaN
# USDe 77%                                             NaN                NaN
# sUSDe 94.50%                                         NaN                NaN
# sUSDe 91.50%                                         NaN                NaN
# sUSDe 86%                                            NaN                NaN
# sUSDe 77%                                            NaN                NaN
# PT-sUSDe-24Oct2024 86%                               NaN                NaN
# PT-sUSDe-26Dec2024 91.5%                             NaN                NaN
# PT-sUSDe-27Mar2025 91.5%                             NaN                NaN
# PT-USDe-27Mar2025 91.5%                              NaN                NaN
# PT-sUSDe-29May2025 91.5%                             NaN                NaN

# %%
idle_df
# Out:
#      LLTV Total Supply Maker Allocation Utilization Borrow Rate
# Idle  NaN          NaN              NaN         NaN         NaN

# %% [markdown]
# ### Retrieve latest values
#
# Connect to BA API and retrieve the data for the pools we are interested in. First define pools by their uuid, to retrieve the data.

# %%
market_to_pool = {
    "db760246f6859780f6c1b272d47a8f64710777121118e56e0cdb4b8b744a3094": 'USDe 94.50%',
    "8e6aeb10c401de3279ac79b4b2ea15fc94b7d9cfc098d6c2a1ff7b2b26d9d02c": 'USDe 91.50%',
    "c581c5f70bd1afa283eed57d1418c6432cbff1d862f94eaf58fdd4e46afbb67f": 'USDe 86%',
    "fd8493f09eb6203615221378d89f53fcd92ff4f7d62cca87eece9a2fff59e86f": 'USDe 77%',
    "e475337d11be1db07f7c5a156e511f05d1844308e66e17d2ba5da0839d3b34d9": 'sUSDe 94.50%',
    "1247f1c237eceae0602eab1470a5061a6dd8f734ba88c7cdc5d6109fb0026b28": 'sUSDe 91.50%',
    "39d11026eae1c6ec02aa4c0910778664089cdd97c3fd23f68f7cd05e2e95af48": 'sUSDe 86%',
    "42dcfb38bb98767afb6e38ccf90d59d0d3f0aa216beb3a234f12850323d17536": 'sUSDe 77%',
    "8f46cd82c4c44a090c3d72bd7a84baf4e69ee50331d5deae514f86fe062b0748": 'PT-sUSDe-24Oct2024 86%',
    "e37784e5ff9c2795395c5a41a0cb7ae1da4a93d67bfdd8654b9ff86b3065941c": 'PT-sUSDe-26Dec2024 91.5%',
    "5e3e6b1e01c5708055548d82d01db741e37d03b948a7ef9f3d4b962648bcbfa7": 'PT-sUSDe-27Mar2025 91.5%',
    "ab0dcab71e65c05b7f241ea79a33452c87e62db387129e4abe15e458d433e4d8": 'PT-USDe-27Mar2025 91.5%',
    "407d8c123443d362ffdfe73208068ef158a21d1a44a988c9acc23a51bade7905": 'PT-sUSDe-29May2025 91.5%'
}

# %%
# market_to_pool.keys()

# %% [markdown]
# Retrieve the data from API

# %%
# Base URL for market data
base_market_url = "https://morpho-api.blockanalitica.com/markets/{}/historic/?days_ago=0&network=ethereum"
# Base URL for wallet data
base_wallet_url = "https://morpho-api.blockanalitica.com/markets/{}/wallets/?network=ethereum&order=-supply&p_size=4&type=suppliers"
# URL for vault data
vaults_url = "https://morpho-api.blockanalitica.com/vaults/0x73e65dbd630f90604062f6e02fab9138e713edd9/pools/?days_ago=0&network=ethereum&order=-supply_usd&p=1&p_size=15"
# URL for SSR rate
ssr_url = "https://info-sky.blockanalitica.com/save/"
# The wallet address we are interested in
target_wallet = "0x73e65dbd630f90604062f6e02fab9138e713edd9"

# Assuming market_to_pool is defined
api_data = ApiBA(base_market_url, base_wallet_url, market_to_pool.keys(), target_wallet, vaults_url, ssr_url)

# %% [markdown]
# With data from API populate the dataframe

# %%
market_data = PoolDataHandler(pools_df, market_to_pool)
pools_df = market_data.populate_dataframe(api_data.fetch_data())
pools_df
# Out:
# Updated DataFrame:
#                          Status   LLTV Total Supply Maker Allocation  \
# USDe 94.50%                 NaN  0.945        56129            52032
# USDe 91.50%                 NaN  0.915     22229369         22229368
# USDe 86%                    NaN   0.86     23336200         23183015
# USDe 77%                    NaN   0.77       100334            99249
# sUSDe 94.50%                NaN  0.945       488997                0
# sUSDe 91.50%                NaN  0.915     32816557         32081403
# sUSDe 86%                   NaN   0.86     48625270         47756669
# sUSDe 77%                   NaN   0.77       101675            75719
# PT-sUSDe-24Oct2024 86%      NaN   0.86           72               71
# PT-sUSDe-26Dec2024 91.5%    NaN  0.915      2958452          2958450
# PT-sUSDe-27Mar2025 91.5%    NaN  0.915    409357618        395286294
# PT-USDe-27Mar2025 91.5%     NaN  0.915     80415567         75199088
# PT-sUSDe-29May2025 91.5%    NaN  0.915            2                0
#
#                          Utilization Borrow Rate Supply Cap Total Borrow  \
# USDe 94.50%                   0.8792       0.047          0          NaN
# USDe 91.50%                   0.8642       0.119  200000000          NaN
# USDe 86%                      0.6767      0.0677  500000000          NaN
# USDe 77%                      0.6141       0.034          0          NaN
# sUSDe 94.50%                  0.7955      0.0965          0          NaN
# sUSDe 91.50%                  0.8421       0.127  200000000          NaN
# sUSDe 86%                     0.8738      0.1188  500000000          NaN
# sUSDe 77%                     0.8308      0.0643          0          NaN
# PT-sUSDe-24Oct2024 86%        0.1468      0.0145          0          NaN
# PT-sUSDe-26Dec2024 91.5%      0.1164      0.0128          0          NaN
# PT-sUSDe-27Mar2025 91.5%      0.7072      0.1363  500000000          NaN
# PT-USDe-27Mar2025 91.5%       0.9988      0.8405  100000000          NaN
# PT-sUSDe-29May2025 91.5%      0.8757      0.2066  200000000          NaN
#
#                          Maker Borrow Optimal Rate Capped Borrow Rate    SSR  \
# USDe 94.50%                       NaN          NaN                NaN  0.125
# USDe 91.50%                       NaN          NaN                NaN  0.125
# USDe 86%                          NaN          NaN                NaN  0.125
# USDe 77%                          NaN          NaN                NaN  0.125
# sUSDe 94.50%                      NaN          NaN                NaN  0.125
# sUSDe 91.50%                      NaN          NaN                NaN  0.125
# sUSDe 86%                         NaN          NaN                NaN  0.125
# sUSDe 77%                         NaN          NaN                NaN  0.125
# PT-sUSDe-24Oct2024 86%            NaN          NaN                NaN  0.125
# PT-sUSDe-26Dec2024 91.5%          NaN          NaN                NaN  0.125
# PT-sUSDe-27Mar2025 91.5%          NaN          NaN                NaN  0.125
# PT-USDe-27Mar2025 91.5%           NaN          NaN                NaN  0.125
# PT-sUSDe-29May2025 91.5%          NaN          NaN                NaN  0.125
#
#                          Fixed Spread Fixed Spread Rate Value  \
# USDe 94.50%                       NaN                     NaN
# USDe 91.50%                       NaN                     NaN
# USDe 86%                          NaN                     NaN
# USDe 77%                          NaN                     NaN
# sUSDe 94.50%                      NaN                     NaN
# sUSDe 91.50%                      NaN                     NaN
# sUSDe 86%                         NaN                     NaN
# sUSDe 77%                         NaN                     NaN
# PT-sUSDe-24Oct2024 86%            NaN                     NaN
# PT-sUSDe-26Dec2024 91.5%          NaN                     NaN
# PT-sUSDe-27Mar2025 91.5%          NaN                     NaN
# PT-USDe-27Mar2025 91.5%           NaN                     NaN
# PT-sUSDe-29May2025 91.5%          NaN                     NaN
#
#                          Fixed Slope per 100M Fixed Slope Proportional Spread  \
# USDe 94.50%                               NaN         NaN                 NaN
# USDe 91.50%                               NaN         NaN                 NaN
# USDe 86%                                  NaN         NaN                 NaN
# USDe 77%                                  NaN         NaN                 NaN
# sUSDe 94.50%                              NaN         NaN                 NaN
# sUSDe 91.50%                              NaN         NaN                 NaN
# sUSDe 86%                                 NaN         NaN                 NaN
# sUSDe 77%                                 NaN         NaN                 NaN
# PT-sUSDe-24Oct2024 86%                    NaN         NaN                 NaN
# PT-sUSDe-26Dec2024 91.5%                  NaN         NaN                 NaN
# PT-sUSDe-27Mar2025 91.5%                  NaN         NaN                 NaN
# PT-USDe-27Mar2025 91.5%                   NaN         NaN                 NaN
# PT-sUSDe-29May2025 91.5%                  NaN         NaN                 NaN
#
#                          Proportional Spread Rate Value  \
# USDe 94.50%                                         NaN
# USDe 91.50%                                         NaN
# USDe 86%                                            NaN
# USDe 77%                                            NaN
# sUSDe 94.50%                                        NaN
# sUSDe 91.50%                                        NaN
# sUSDe 86%                                           NaN
# sUSDe 77%                                           NaN
# PT-sUSDe-24Oct2024 86%                              NaN
# PT-sUSDe-26Dec2024 91.5%                            NaN
# PT-sUSDe-27Mar2025 91.5%                            NaN
# PT-USDe-27Mar2025 91.5%                             NaN
# PT-sUSDe-29May2025 91.5%                            NaN
#
#                          Proportional Spread Fixed Value  \
# USDe 94.50%                                          NaN
# USDe 91.50%                                          NaN
# USDe 86%                                             NaN
# USDe 77%                                             NaN
# sUSDe 94.50%                                         NaN
# sUSDe 91.50%                                         NaN
# sUSDe 86%                                            NaN
# sUSDe 77%                                            NaN
# PT-sUSDe-24Oct2024 86%                               NaN
# PT-sUSDe-26Dec2024 91.5%                             NaN
# PT-sUSDe-27Mar2025 91.5%                             NaN
# PT-USDe-27Mar2025 91.5%                              NaN
# PT-sUSDe-29May2025 91.5%                             NaN
#
#                          Proportional Slope per 100M Proportional Slope  \
# USDe 94.50%                                      NaN                NaN
# USDe 91.50%                                      NaN                NaN
# USDe 86%                                         NaN                NaN
# USDe 77%                                         NaN                NaN
# sUSDe 94.50%                                     NaN                NaN
# sUSDe 91.50%                                     NaN                NaN
# sUSDe 86%                                        NaN                NaN
# sUSDe 77%                                        NaN                NaN
# PT-sUSDe-24Oct2024 86%                           NaN                NaN
# PT-sUSDe-26Dec2024 91.5%                         NaN                NaN
# PT-sUSDe-27Mar2025 91.5%                         NaN                NaN
# PT-USDe-27Mar2025 91.5%                          NaN                NaN
# PT-sUSDe-29May2025 91.5%                         NaN                NaN
#
#                          Proportional Slope Fixed Value Low Target Threshold  \
# USDe 94.50%                                         NaN                  NaN
# USDe 91.50%                                         NaN                  NaN
# USDe 86%                                            NaN                  NaN
# USDe 77%                                            NaN                  NaN
# sUSDe 94.50%                                        NaN                  NaN
# sUSDe 91.50%                                        NaN                  NaN
# sUSDe 86%                                           NaN                  NaN
# sUSDe 77%                                           NaN                  NaN
# PT-sUSDe-24Oct2024 86%                              NaN                  NaN
# PT-sUSDe-26Dec2024 91.5%                            NaN                  NaN
# PT-sUSDe-27Mar2025 91.5%                            NaN                  NaN
# PT-USDe-27Mar2025 91.5%                             NaN                  NaN
# PT-sUSDe-29May2025 91.5%                            NaN                  NaN
#
#                          High Target Threshold Target Borrow Rate  \
# USDe 94.50%                                NaN                NaN
# USDe 91.50%                                NaN                NaN
# USDe 86%                                   NaN                NaN
# USDe 77%                                   NaN                NaN
# sUSDe 94.50%                               NaN                NaN
# sUSDe 91.50%                               NaN                NaN
# sUSDe 86%                                  NaN                NaN
# sUSDe 77%                                  NaN                NaN
# PT-sUSDe-24Oct2024 86%                     NaN                NaN
# PT-sUSDe-26Dec2024 91.5%                   NaN                NaN
# PT-sUSDe-27Mar2025 91.5%                   NaN                NaN
# PT-USDe-27Mar2025 91.5%                    NaN                NaN
# PT-sUSDe-29May2025 91.5%                   NaN                NaN
#
#                          Min Borrow Rate Max Borrow Rate  \
# USDe 94.50%                          NaN             NaN
# USDe 91.50%                          NaN             NaN
# USDe 86%                             NaN             NaN
# USDe 77%                             NaN             NaN
# sUSDe 94.50%                         NaN             NaN
# sUSDe 91.50%                         NaN             NaN
# sUSDe 86%                            NaN             NaN
# sUSDe 77%                            NaN             NaN
# PT-sUSDe-24Oct2024 86%               NaN             NaN
# PT-sUSDe-26Dec2024 91.5%             NaN             NaN
# PT-sUSDe-27Mar2025 91.5%             NaN             NaN
# PT-USDe-27Mar2025 91.5%              NaN             NaN
# PT-sUSDe-29May2025 91.5%             NaN             NaN
#
#                          Utilization Where Rate Equal to SSR SSR Adjustment  \
# USDe 94.50%                                              NaN            NaN
# USDe 91.50%                                              NaN            NaN
# USDe 86%                                                 NaN            NaN
# USDe 77%                                                 NaN            NaN
# sUSDe 94.50%                                             NaN            NaN
# sUSDe 91.50%                                             NaN            NaN
# sUSDe 86%                                                NaN            NaN
# sUSDe 77%                                                NaN            NaN
# PT-sUSDe-24Oct2024 86%                                   NaN            NaN
# PT-sUSDe-26Dec2024 91.5%                                 NaN            NaN
# PT-sUSDe-27Mar2025 91.5%                                 NaN            NaN
# PT-USDe-27Mar2025 91.5%                                  NaN            NaN
# PT-sUSDe-29May2025 91.5%                                 NaN            NaN
#
#                          Total Supply After SSR Adjustment  \
# USDe 94.50%                                            NaN
# USDe 91.50%                                            NaN
# USDe 86%                                               NaN
# USDe 77%                                               NaN
# sUSDe 94.50%                                           NaN
# sUSDe 91.50%                                           NaN
# sUSDe 86%                                              NaN
# sUSDe 77%                                              NaN
# PT-sUSDe-24Oct2024 86%                                 NaN
# PT-sUSDe-26Dec2024 91.5%                               NaN
# PT-sUSDe-27Mar2025 91.5%                               NaN
# PT-USDe-27Mar2025 91.5%                                NaN
# PT-sUSDe-29May2025 91.5%                               NaN
#
#                          Maker Supply After SSR Adjustment  \
# USDe 94.50%                                            NaN
# USDe 91.50%                                            NaN
# USDe 86%                                               NaN
# USDe 77%                                               NaN
# sUSDe 94.50%                                           NaN
# sUSDe 91.50%                                           NaN
# sUSDe 86%                                              NaN
# sUSDe 77%                                              NaN
# PT-sUSDe-24Oct2024 86%                                 NaN
# PT-sUSDe-26Dec2024 91.5%                               NaN
# PT-sUSDe-27Mar2025 91.5%                               NaN
# PT-USDe-27Mar2025 91.5%                                NaN
# PT-sUSDe-29May2025 91.5%                               NaN
#
#                          Utilization After SSR Adjustment Inactive Withdrawal  \
# USDe 94.50%                                           NaN                 NaN
# USDe 91.50%                                           NaN                 NaN
# USDe 86%                                              NaN                 NaN
# USDe 77%                                              NaN                 NaN
# sUSDe 94.50%                                          NaN                 NaN
# sUSDe 91.50%                                          NaN                 NaN
# sUSDe 86%                                             NaN                 NaN
# sUSDe 77%                                             NaN                 NaN
# PT-sUSDe-24Oct2024 86%                                NaN                 NaN
# PT-sUSDe-26Dec2024 91.5%                              NaN                 NaN
# PT-sUSDe-27Mar2025 91.5%                              NaN                 NaN
# PT-USDe-27Mar2025 91.5%                               NaN                 NaN
# PT-sUSDe-29May2025 91.5%                              NaN                 NaN
#
#                          Utilization Where Rate Equal To Min Target  \
# USDe 94.50%                                                     NaN
# USDe 91.50%                                                     NaN
# USDe 86%                                                        NaN
# USDe 77%                                                        NaN
# sUSDe 94.50%                                                    NaN
# sUSDe 91.50%                                                    NaN
# sUSDe 86%                                                       NaN
# sUSDe 77%                                                       NaN
# PT-sUSDe-24Oct2024 86%                                          NaN
# PT-sUSDe-26Dec2024 91.5%                                        NaN
# PT-sUSDe-27Mar2025 91.5%                                        NaN
# PT-USDe-27Mar2025 91.5%                                         NaN
# PT-sUSDe-29May2025 91.5%                                        NaN
#
#                          Active Withdrawal  \
# USDe 94.50%                            NaN
# USDe 91.50%                            NaN
# USDe 86%                               NaN
# USDe 77%                               NaN
# sUSDe 94.50%                           NaN
# sUSDe 91.50%                           NaN
# sUSDe 86%                              NaN
# sUSDe 77%                              NaN
# PT-sUSDe-24Oct2024 86%                 NaN
# PT-sUSDe-26Dec2024 91.5%               NaN
# PT-sUSDe-27Mar2025 91.5%               NaN
# PT-USDe-27Mar2025 91.5%                NaN
# PT-sUSDe-29May2025 91.5%               NaN
#
#                          Utilization Where Rate Equal To Max Target  \
# USDe 94.50%                                                     NaN
# USDe 91.50%                                                     NaN
# USDe 86%                                                        NaN
# USDe 77%                                                        NaN
# sUSDe 94.50%                                                    NaN
# sUSDe 91.50%                                                    NaN
# sUSDe 86%                                                       NaN
# sUSDe 77%                                                       NaN
# PT-sUSDe-24Oct2024 86%                                          NaN
# PT-sUSDe-26Dec2024 91.5%                                        NaN
# PT-sUSDe-27Mar2025 91.5%                                        NaN
# PT-USDe-27Mar2025 91.5%                                         NaN
# PT-sUSDe-29May2025 91.5%                                        NaN
#
#                          Active Deposits Manual Adjustment Total Change  \
# USDe 94.50%                          NaN               NaN          NaN
# USDe 91.50%                          NaN               NaN          NaN
# USDe 86%                             NaN               NaN          NaN
# USDe 77%                             NaN               NaN          NaN
# sUSDe 94.50%                         NaN               NaN          NaN
# sUSDe 91.50%                         NaN               NaN          NaN
# sUSDe 86%                            NaN               NaN          NaN
# sUSDe 77%                            NaN               NaN          NaN
# PT-sUSDe-24Oct2024 86%               NaN               NaN          NaN
# PT-sUSDe-26Dec2024 91.5%             NaN               NaN          NaN
# PT-sUSDe-27Mar2025 91.5%             NaN               NaN          NaN
# PT-USDe-27Mar2025 91.5%              NaN               NaN          NaN
# PT-sUSDe-29May2025 91.5%             NaN               NaN          NaN
#
#                          Final Allocation Final Supply Final Utilization  \
# USDe 94.50%                           NaN          NaN               NaN
# USDe 91.50%                           NaN          NaN               NaN
# USDe 86%                              NaN          NaN               NaN
# USDe 77%                              NaN          NaN               NaN
# sUSDe 94.50%                          NaN          NaN               NaN
# sUSDe 91.50%                          NaN          NaN               NaN
# sUSDe 86%                             NaN          NaN               NaN
# sUSDe 77%                             NaN          NaN               NaN
# PT-sUSDe-24Oct2024 86%                NaN          NaN               NaN
# PT-sUSDe-26Dec2024 91.5%              NaN          NaN               NaN
# PT-sUSDe-27Mar2025 91.5%              NaN          NaN               NaN
# PT-USDe-27Mar2025 91.5%               NaN          NaN               NaN
# PT-sUSDe-29May2025 91.5%              NaN          NaN               NaN
#
#                          Final Borrow Rate Final Capped Rate  \
# USDe 94.50%                            NaN               NaN
# USDe 91.50%                            NaN               NaN
# USDe 86%                               NaN               NaN
# USDe 77%                               NaN               NaN
# sUSDe 94.50%                           NaN               NaN
# sUSDe 91.50%                           NaN               NaN
# sUSDe 86%                              NaN               NaN
# sUSDe 77%                              NaN               NaN
# PT-sUSDe-24Oct2024 86%                 NaN               NaN
# PT-sUSDe-26Dec2024 91.5%               NaN               NaN
# PT-sUSDe-27Mar2025 91.5%               NaN               NaN
# PT-USDe-27Mar2025 91.5%                NaN               NaN
# PT-sUSDe-29May2025 91.5%               NaN               NaN
#
#                          Maker Borrow at Old Utilization Borrow Rate Change
# USDe 94.50%                                          NaN                NaN
# USDe 91.50%                                          NaN                NaN
# USDe 86%                                             NaN                NaN
# USDe 77%                                             NaN                NaN
# sUSDe 94.50%                                         NaN                NaN
# sUSDe 91.50%                                         NaN                NaN
# sUSDe 86%                                            NaN                NaN
# sUSDe 77%                                            NaN                NaN
# PT-sUSDe-24Oct2024 86%                               NaN                NaN
# PT-sUSDe-26Dec2024 91.5%                             NaN                NaN
# PT-sUSDe-27Mar2025 91.5%                             NaN                NaN
# PT-USDe-27Mar2025 91.5%                              NaN                NaN
# PT-sUSDe-29May2025 91.5%                             NaN                NaN

# %%
#index_to_drop = 'sUSDe 77%PT-sUSDe-24Oct2024 86%'
#pools_df = pools_df.drop(index_to_drop)

# %% [markdown]
# To see the allocation in the Idle matket:

# %%
idle_market_to_pool = {"57f4e42c0707d3ae0ae39c9343dcba78ff79fa663da040eca45717a9b0b0557f": 'Idle'}
idle_api_data = ApiBA(base_market_url, base_wallet_url, idle_market_to_pool.keys(), target_wallet, vaults_url, ssr_url)
idle_data = PoolDataHandler(idle_df, idle_market_to_pool)
idle_df = idle_data.populate_dataframe(idle_api_data.fetch_data())
idle_df
# Out:
# Updated DataFrame:
#      LLTV Total Supply Maker Allocation Utilization Borrow Rate  \
# Idle  0.0     27665893         27665893         0.0         0.0
#
#                                   Supply Cap    SSR
# Idle  24519928653854223487948685977518604288  0.125

# %% [markdown]
# ### Reallocation Metaparameters
#
# They are set as done by Monet. Change only in case you know what you are doing!

# %%
realloc_metaparm = {
    'active_pool' : {
        'min_balance' : 10000000,
        'max_utilization' : 0.9,
        'max_portion_to_withdraw' : 0.1,
        'allocation_significance_threshold' : 10000,
    },
    'inactive_pool' : {
        'min_balance' : 100000,
        'max_utilization' : 0.93,
        'max_portion_to_withdraw' : 1,
        'allocation_significance_threshold' : 10000,
    },
}

# %%
pools_analysis = PoolAnalysis(pools_df, idle_df, realloc_metaparm)

# %% [markdown]
# #### Classify market as Active or Inactive
#
# Change the status of the pool you want to change by changing the pool status to `Active` or `Inactive`

# %%
pools_df.loc['USDe 94.50%', 'Status'] = 'Inactive'
pools_df.loc['USDe 91.50%', 'Status'] = 'Active'
pools_df.loc['USDe 86%', 'Status'] = 'Active'
pools_df.loc['USDe 77%', 'Status'] = 'Inactive'
pools_df.loc['sUSDe 94.50%', 'Status'] = 'Inactive'
pools_df.loc['sUSDe 91.50%', 'Status'] = 'Active'
pools_df.loc['sUSDe 86%', 'Status'] = 'Active'
pools_df.loc['sUSDe 77%', 'Status'] = 'Inactive'
pools_df.loc['PT-sUSDe-24Oct2024 86%', 'Status'] = 'Inactive'
pools_df.loc['PT-sUSDe-26Dec2024 91.5%', 'Status'] = 'Inactive'
pools_df.loc['PT-sUSDe-27Mar2025 91.5%', 'Status'] = 'Active'
pools_df.loc['PT-USDe-27Mar2025 91.5%', 'Status'] = 'Active'
pools_df.loc['PT-sUSDe-29May2025 91.5%', 'Status'] = 'Active'

# %% [markdown]
# ## Vault benchmarks
#
# Here you can modify the vault benchmark calculations.

# %%
# Tweakable parameters
pools_df['Fixed Spread'] = 1.75 / 100
pools_df['Fixed Slope per 100M'] = 0.65 / 100

pools_df['Proportional Spread'] = 50 / 100
pools_df['Proportional Slope per 100M'] = 3 / 100

pools_df['Low Target Threshold'] = 80 / 100
pools_df['High Target Threshold'] = 105 / 100

# Indirect parameters
pools_df['Fixed Spread Rate Value'] = pools_df['SSR'] + pools_df['Fixed Spread']
pools_df['Fixed Slope'] = pools_df['Fixed Slope per 100M'] / 100000000
pools_df['Proportional Spread Rate Value'] = pools_df['SSR'] * (1 + pools_df['Proportional Spread'])
pools_df['Proportional Spread Fixed Value'] = pools_df['Proportional Spread Rate Value'] - pools_df['SSR']
pools_df['Proportional Slope'] = pools_df['Proportional Slope per 100M'] / 100000000
pools_df['Proportional Slope Fixed Value'] = pools_df['Proportional Spread Rate Value'] * pools_df['Proportional Slope per 100M']

# %%
#pools_analysis.define_active_or_inactive()

# %% [markdown]
# ### Manual Adjustment
#
# If you want to add a manual adjustment, do it here by uncommenting the line of code with pool you want to adjust and change the number inside the parenthesis.

# %%
#pools_df.loc['USDe 94.50%', 'Manual Adjustment'] = int(0)
#pools_df.loc['USDe 91.50%', 'Manual Adjustment'] = int(0)
#pools_df.loc['USDe 86%', 'Manual Adjustment'] = int(0)
#pools_df.loc['USDe 77%', 'Manual Adjustment'] = int(0)
#pools_df.loc['sUSDe 94.50%', 'Manual Adjustment'] = int(0)
#pools_df.loc['sUSDe 91.50%', 'Manual Adjustment'] = int(0)
#pools_df.loc['sUSDe 86%', 'Manual Adjustment'] = int(0)
#pools_df.loc['sUSDe 77%', 'Manual Adjustment'] = int(0)
#pools_df.loc['PT-sUSDe-24Oct2024 86%', 'Manual Adjustment'] = int(0)
#pools_df.loc['PT-sUSDe-26Dec2024 91.5%', 'Manual Adjustment'] = int(0)
#pools_df.loc['PT-sUSDe-27Mar2025 91.5%', 'Manual Adjustment'] = int(0)
#pools_df.loc['PT-USDe-27Mar2025 91.5%', 'Manual Adjustment'] = int(0)
#pools_df.loc['PT-sUSDe-29May2025 91.5%', 'Manual Adjustment'] = int(0)

# %% [markdown]
# ### Reallocation Dataframe
#
# Get the final table with all data. For easier overview focus on the following tables

# %%
pools_analysis = PoolAnalysis(pools_df, idle_df, realloc_metaparm)

# %%
pools_analysis.update_pool_dataframe()
# Out:
#                             Status   LLTV Total Supply Maker Allocation  \
# USDe 94.50%               Inactive  0.945        56129            52032
# USDe 91.50%                 Active  0.915     22229369         22229368
# USDe 86%                    Active   0.86     23336200         23183015
# USDe 77%                  Inactive   0.77       100334            99249
# sUSDe 94.50%              Inactive  0.945       488997                0
# sUSDe 91.50%                Active  0.915     32816557         32081403
# sUSDe 86%                   Active   0.86     48625270         47756669
# sUSDe 77%                 Inactive   0.77       101675            75719
# PT-sUSDe-24Oct2024 86%    Inactive   0.86           72               71
# PT-sUSDe-26Dec2024 91.5%  Inactive  0.915      2958452          2958450
# PT-sUSDe-27Mar2025 91.5%    Active  0.915    409357618        395286294
# PT-USDe-27Mar2025 91.5%     Active  0.915     80415567         75199088
# PT-sUSDe-29May2025 91.5%    Active  0.915            2                0
#
#                          Utilization Borrow Rate Supply Cap Total Borrow  \
# USDe 94.50%                   0.8792       0.047          0        49348
# USDe 91.50%                   0.8642       0.119  200000000     19210620
# USDe 86%                      0.6767      0.0677  500000000     15791606
# USDe 77%                      0.6141       0.034          0        61615
# sUSDe 94.50%                  0.7955      0.0965          0       388997
# sUSDe 91.50%                  0.8421       0.127  200000000     27634822
# sUSDe 86%                     0.8738      0.1188  500000000     42488760
# sUSDe 77%                     0.8308      0.0643          0        84471
# PT-sUSDe-24Oct2024 86%        0.1468      0.0145          0           10
# PT-sUSDe-26Dec2024 91.5%      0.1164      0.0128          0       344363
# PT-sUSDe-27Mar2025 91.5%      0.7072      0.1363  500000000    289497707
# PT-USDe-27Mar2025 91.5%       0.9988      0.8405  100000000     80319068
# PT-sUSDe-29May2025 91.5%      0.8757      0.2066  200000000            1
#
#                          Maker Borrow Optimal Rate Capped Borrow Rate    SSR  \
# USDe 94.50%                     45745       0.0478              0.047  0.125
# USDe 91.50%                  19210619       0.1227              0.119  0.125
# USDe 86%                     15687945       0.0832             0.0677  0.125
# USDe 77%                        60948       0.0446              0.034  0.125
# sUSDe 94.50%                        0       0.1057             0.0965  0.125
# sUSDe 91.50%                 27015748       0.1334              0.127  0.125
# sUSDe 86%                    41729776       0.1215             0.1188  0.125
# sUSDe 77%                       62906       0.0682             0.0643  0.125
# PT-sUSDe-24Oct2024 86%              9       0.0389             0.0145  0.125
# PT-sUSDe-26Dec2024 91.5%       344362       0.0369             0.0128  0.125
# PT-sUSDe-27Mar2025 91.5%    279546466       0.1624             0.1363  0.125
# PT-USDe-27Mar2025 91.5%      75108848        0.212              0.212  0.125
# PT-sUSDe-29May2025 91.5%            0       0.2109             0.2066  0.125
#
#                           Fixed Spread Fixed Spread Rate Value  \
# USDe 94.50%                     0.0175                  0.1425
# USDe 91.50%                     0.0175                  0.1425
# USDe 86%                        0.0175                  0.1425
# USDe 77%                        0.0175                  0.1425
# sUSDe 94.50%                    0.0175                  0.1425
# sUSDe 91.50%                    0.0175                  0.1425
# sUSDe 86%                       0.0175                  0.1425
# sUSDe 77%                       0.0175                  0.1425
# PT-sUSDe-24Oct2024 86%          0.0175                  0.1425
# PT-sUSDe-26Dec2024 91.5%        0.0175                  0.1425
# PT-sUSDe-27Mar2025 91.5%        0.0175                  0.1425
# PT-USDe-27Mar2025 91.5%         0.0175                  0.1425
# PT-sUSDe-29May2025 91.5%        0.0175                  0.1425
#
#                           Fixed Slope per 100M   Fixed Slope  \
# USDe 94.50%                             0.0065  6.500000e-11
# USDe 91.50%                             0.0065  6.500000e-11
# USDe 86%                                0.0065  6.500000e-11
# USDe 77%                                0.0065  6.500000e-11
# sUSDe 94.50%                            0.0065  6.500000e-11
# sUSDe 91.50%                            0.0065  6.500000e-11
# sUSDe 86%                               0.0065  6.500000e-11
# sUSDe 77%                               0.0065  6.500000e-11
# PT-sUSDe-24Oct2024 86%                  0.0065  6.500000e-11
# PT-sUSDe-26Dec2024 91.5%                0.0065  6.500000e-11
# PT-sUSDe-27Mar2025 91.5%                0.0065  6.500000e-11
# PT-USDe-27Mar2025 91.5%                 0.0065  6.500000e-11
# PT-sUSDe-29May2025 91.5%                0.0065  6.500000e-11
#
#                           Proportional Spread Proportional Spread Rate Value  \
# USDe 94.50%                               0.5                         0.1875
# USDe 91.50%                               0.5                         0.1875
# USDe 86%                                  0.5                         0.1875
# USDe 77%                                  0.5                         0.1875
# sUSDe 94.50%                              0.5                         0.1875
# sUSDe 91.50%                              0.5                         0.1875
# sUSDe 86%                                 0.5                         0.1875
# sUSDe 77%                                 0.5                         0.1875
# PT-sUSDe-24Oct2024 86%                    0.5                         0.1875
# PT-sUSDe-26Dec2024 91.5%                  0.5                         0.1875
# PT-sUSDe-27Mar2025 91.5%                  0.5                         0.1875
# PT-USDe-27Mar2025 91.5%                   0.5                         0.1875
# PT-sUSDe-29May2025 91.5%                  0.5                         0.1875
#
#                          Proportional Spread Fixed Value  \
# USDe 94.50%                                       0.0625
# USDe 91.50%                                       0.0625
# USDe 86%                                          0.0625
# USDe 77%                                          0.0625
# sUSDe 94.50%                                      0.0625
# sUSDe 91.50%                                      0.0625
# sUSDe 86%                                         0.0625
# sUSDe 77%                                         0.0625
# PT-sUSDe-24Oct2024 86%                            0.0625
# PT-sUSDe-26Dec2024 91.5%                          0.0625
# PT-sUSDe-27Mar2025 91.5%                          0.0625
# PT-USDe-27Mar2025 91.5%                           0.0625
# PT-sUSDe-29May2025 91.5%                          0.0625
#
#                           Proportional Slope per 100M  Proportional Slope  \
# USDe 94.50%                                      0.03        3.000000e-10
# USDe 91.50%                                      0.03        3.000000e-10
# USDe 86%                                         0.03        3.000000e-10
# USDe 77%                                         0.03        3.000000e-10
# sUSDe 94.50%                                     0.03        3.000000e-10
# sUSDe 91.50%                                     0.03        3.000000e-10
# sUSDe 86%                                        0.03        3.000000e-10
# sUSDe 77%                                        0.03        3.000000e-10
# PT-sUSDe-24Oct2024 86%                           0.03        3.000000e-10
# PT-sUSDe-26Dec2024 91.5%                         0.03        3.000000e-10
# PT-sUSDe-27Mar2025 91.5%                         0.03        3.000000e-10
# PT-USDe-27Mar2025 91.5%                          0.03        3.000000e-10
# PT-sUSDe-29May2025 91.5%                         0.03        3.000000e-10
#
#                          Proportional Slope Fixed Value  Low Target Threshold  \
# USDe 94.50%                                    0.005625                   0.8
# USDe 91.50%                                    0.005625                   0.8
# USDe 86%                                       0.005625                   0.8
# USDe 77%                                       0.005625                   0.8
# sUSDe 94.50%                                   0.005625                   0.8
# sUSDe 91.50%                                   0.005625                   0.8
# sUSDe 86%                                      0.005625                   0.8
# sUSDe 77%                                      0.005625                   0.8
# PT-sUSDe-24Oct2024 86%                         0.005625                   0.8
# PT-sUSDe-26Dec2024 91.5%                       0.005625                   0.8
# PT-sUSDe-27Mar2025 91.5%                       0.005625                   0.8
# PT-USDe-27Mar2025 91.5%                        0.005625                   0.8
# PT-sUSDe-29May2025 91.5%                       0.005625                   0.8
#
#                           High Target Threshold Target Borrow Rate  \
# USDe 94.50%                                1.05             0.2227
# USDe 91.50%                                1.05             0.2227
# USDe 86%                                   1.05             0.2227
# USDe 77%                                   1.05             0.2227
# sUSDe 94.50%                               1.05             0.2227
# sUSDe 91.50%                               1.05             0.2227
# sUSDe 86%                                  1.05             0.2227
# sUSDe 77%                                  1.05             0.2227
# PT-sUSDe-24Oct2024 86%                     1.05             0.2227
# PT-sUSDe-26Dec2024 91.5%                   1.05             0.2227
# PT-sUSDe-27Mar2025 91.5%                   1.05             0.2227
# PT-USDe-27Mar2025 91.5%                    1.05             0.2227
# PT-sUSDe-29May2025 91.5%                   1.05             0.2227
#
#                          Min Borrow Rate Max Borrow Rate  \
# USDe 94.50%                       0.1782          0.2338
# USDe 91.50%                       0.1782          0.2338
# USDe 86%                          0.1782          0.2338
# USDe 77%                          0.1782          0.2338
# sUSDe 94.50%                      0.1782          0.2338
# sUSDe 91.50%                      0.1782          0.2338
# sUSDe 86%                         0.1782          0.2338
# sUSDe 77%                         0.1782          0.2338
# PT-sUSDe-24Oct2024 86%            0.1782          0.2338
# PT-sUSDe-26Dec2024 91.5%          0.1782          0.2338
# PT-sUSDe-27Mar2025 91.5%          0.1782          0.2338
# PT-USDe-27Mar2025 91.5%           0.1782          0.2338
# PT-sUSDe-29May2025 91.5%          0.1782          0.2338
#
#                          Utilization Where Rate Equal to SSR SSR Adjustment  \
# USDe 94.50%                                           0.9538              0
# USDe 91.50%                                           0.9006        -898456
# USDe 86%                                              0.9167       -6109619
# USDe 77%                                              0.9601           -334
# sUSDe 94.50%                                          0.9061              0
# sUSDe 91.50%                                          0.8244              0
# sUSDe 86%                                              0.901       -1467933
# sUSDe 77%                                             0.9278          -1675
# PT-sUSDe-24Oct2024 86%                                0.9738              0
# PT-sUSDe-26Dec2024 91.5%                              0.9796       -2606917
# PT-sUSDe-27Mar2025 91.5%                              0.6236              0
# PT-USDe-27Mar2025 91.5%                               0.4075              0
# PT-sUSDe-29May2025 91.5%                              0.4112              0
#
#                          Total Supply After SSR Adjustment  \
# USDe 94.50%                                          56129
# USDe 91.50%                                       21330913
# USDe 86%                                          17226581
# USDe 77%                                            100000
# sUSDe 94.50%                                        488997
# sUSDe 91.50%                                      32816557
# sUSDe 86%                                         47157337
# sUSDe 77%                                           100000
# PT-sUSDe-24Oct2024 86%                                  72
# PT-sUSDe-26Dec2024 91.5%                            351535
# PT-sUSDe-27Mar2025 91.5%                         409357618
# PT-USDe-27Mar2025 91.5%                           80415567
# PT-sUSDe-29May2025 91.5%                                 2
#
#                          Maker Supply After SSR Adjustment  \
# USDe 94.50%                                          52032
# USDe 91.50%                                       21330912
# USDe 86%                                          17073396
# USDe 77%                                             98915
# sUSDe 94.50%                                             0
# sUSDe 91.50%                                      32081403
# sUSDe 86%                                         46288736
# sUSDe 77%                                            74044
# PT-sUSDe-24Oct2024 86%                                  71
# PT-sUSDe-26Dec2024 91.5%                            351533
# PT-sUSDe-27Mar2025 91.5%                         395286294
# PT-USDe-27Mar2025 91.5%                           75199088
# PT-sUSDe-29May2025 91.5%                                 0
#
#                          Utilization After SSR Adjustment Inactive Withdrawal  \
# USDe 94.50%                                        0.8792                   0
# USDe 91.50%                                        0.9006                   0
# USDe 86%                                           0.9167                   0
# USDe 77%                                           0.6161                   0
# sUSDe 94.50%                                       0.7955                   0
# sUSDe 91.50%                                       0.8421                   0
# sUSDe 86%                                           0.901                   0
# sUSDe 77%                                          0.8447                   0
# PT-sUSDe-24Oct2024 86%                             0.1389                   0
# PT-sUSDe-26Dec2024 91.5%                           0.9796                   0
# PT-sUSDe-27Mar2025 91.5%                           0.7072                   0
# PT-USDe-27Mar2025 91.5%                            0.9988                   0
# PT-sUSDe-29May2025 91.5%                              0.5                   0
#
#                          Utilization Where Rate Equal To Min Target  \
# USDe 94.50%                                                  0.9909
# USDe 91.50%                                                  0.9151
# USDe 86%                                                     0.9381
# USDe 77%                                                     0.9999
# sUSDe 94.50%                                                 0.9229
# sUSDe 91.50%                                                 0.9112
# sUSDe 86%                                                    0.9156
# sUSDe 77%                                                    0.9538
# PT-sUSDe-24Oct2024 86%                                            1
# PT-sUSDe-26Dec2024 91.5%                                          1
# PT-sUSDe-27Mar2025 91.5%                                     0.9032
# PT-USDe-27Mar2025 91.5%                                      0.7087
# PT-sUSDe-29May2025 91.5%                                     0.7139
#
#                          Active Withdrawal  \
# USDe 94.50%                              0
# USDe 91.50%                              0
# USDe 86%                                 0
# USDe 77%                                 0
# sUSDe 94.50%                             0
# sUSDe 91.50%                      -2111199
# sUSDe 86%                                0
# sUSDe 77%                                0
# PT-sUSDe-24Oct2024 86%                   0
# PT-sUSDe-26Dec2024 91.5%                 0
# PT-sUSDe-27Mar2025 91.5%         -40935761
# PT-USDe-27Mar2025 91.5%                  0
# PT-sUSDe-29May2025 91.5%                 0
#
#                          Utilization Where Rate Equal To Max Target  \
# USDe 94.50%                                                       1
# USDe 91.50%                                                  0.9302
# USDe 86%                                                     0.9603
# USDe 77%                                                          1
# sUSDe 94.50%                                                 0.9404
# sUSDe 91.50%                                                 0.9251
# sUSDe 86%                                                    0.9308
# sUSDe 77%                                                    0.9809
# PT-sUSDe-24Oct2024 86%                                            1
# PT-sUSDe-26Dec2024 91.5%                                          1
# PT-sUSDe-27Mar2025 91.5%                                     0.9147
# PT-USDe-27Mar2025 91.5%                                      0.9034
# PT-sUSDe-29May2025 91.5%                                     0.9036
#
#                          Active Deposits Manual Adjustment    Total Change  \
# USDe 94.50%                            0                 0               0
# USDe 91.50%                            0                 0         -898456
# USDe 86%                               0                 0        -6109619
# USDe 77%                               0                 0               0
# sUSDe 94.50%                           0                 0               0
# sUSDe 91.50%                           0                 0        -2111199
# sUSDe 86%                              0                 0        -1467933
# sUSDe 77%                              0                 0               0
# PT-sUSDe-24Oct2024 86%                 0                 0               0
# PT-sUSDe-26Dec2024 91.5%               0                 0        -2606917
# PT-sUSDe-27Mar2025 91.5%               0                 0       -40935761
# PT-USDe-27Mar2025 91.5%   8491968.975205                 0  8491968.975205
# PT-sUSDe-29May2025 91.5%               0                 0               0
#
#                          Final Allocation Final Supply Final Utilization  \
# USDe 94.50%                         52032        56129            0.8792
# USDe 91.50%                      21330912     21330913            0.9006
# USDe 86%                         17073396     17226581            0.9167
# USDe 77%                            99249       100334            0.6141
# sUSDe 94.50%                            0       488997            0.7955
# sUSDe 91.50%                     29970204     30705358               0.9
# sUSDe 86%                        46288736     47157337             0.901
# sUSDe 77%                           75719       101675            0.8308
# PT-sUSDe-24Oct2024 86%                 71           72            0.1389
# PT-sUSDe-26Dec2024 91.5%           351533       351535            0.9796
# PT-sUSDe-27Mar2025 91.5%        354350533    368421857            0.7858
# PT-USDe-27Mar2025 91.5%          83691056     88907535            0.9034
# PT-sUSDe-29May2025 91.5%                0            2               0.5
#
#                          Final Borrow Rate Final Capped Rate  \
# USDe 94.50%                          0.047             0.047
# USDe 91.50%                         0.1249            0.1227
# USDe 86%                            0.1249            0.0832
# USDe 77%                             0.034             0.034
# sUSDe 94.50%                        0.0965            0.0965
# sUSDe 91.50%                        0.1334            0.1334
# sUSDe 86%                           0.1251            0.1215
# sUSDe 77%                           0.0643            0.0643
# PT-sUSDe-24Oct2024 86%              0.0142            0.0142
# PT-sUSDe-26Dec2024 91.5%             0.125            0.0369
# PT-sUSDe-27Mar2025 91.5%            0.1469            0.1469
# PT-USDe-27Mar2025 91.5%             0.2336             0.212
# PT-sUSDe-29May2025 91.5%            0.1406            0.1406
#
#                          Maker Borrow at Old Utilization Borrow Rate Change
# USDe 94.50%                                        45746                0.0
# USDe 91.50%                                     18434174             0.0059
# USDe 86%                                        11553567             0.0572
# USDe 77%                                           60948                0.0
# sUSDe 94.50%                                           0                0.0
# sUSDe 91.50%                                    25237908             0.0064
# sUSDe 86%                                       40447097             0.0063
# sUSDe 77%                                          62907                0.0
# PT-sUSDe-24Oct2024 86%                                10            -0.0003
# PT-sUSDe-26Dec2024 91.5%                           40918             0.1122
# PT-sUSDe-27Mar2025 91.5%                       250596696             0.0106
# PT-USDe-27Mar2025 91.5%                         83590626            -0.6069
# PT-sUSDe-29May2025 91.5%                               0             -0.066

# %% [markdown]
# Save the data if you want to perform later analysis or visualizations on this

# %%
#pools_analysis.pool_df.to_json(f'reallocations_{datetime.datetime.now().strftime('%Y_%m_%d')}.json')

# %% [markdown]
# ### Average Utilization, Net and Running Change
#
# Some basic statistics for reallocation

# %%
average_utilization = pools_analysis.pool_df['Utilization'].mean()
print(f'The average utilization of the pools is: {average_utilization * 100:.2f}%')
# Out:
# The average utilization of the pools is: 70.93%

# %% [markdown]
# The net changes based on the type of adjusment are as follows

# %%
net_change_df = pools_analysis.pool_df[['SSR Adjustment', 'Inactive Withdrawal', 'Active Withdrawal', 'Active Deposits', 'Manual Adjustment']].agg('sum').to_frame().T
net_change_df.columns = ['SSR Adjustment Sum', 'Inactive Withdrawal Sum', 'Active Withdrawal Sum', 'Active Deposits Sum', 'Manual Adjustment Sum']
net_change_df = net_change_df.round(0).astype(int)

net_change_df
# Out:
#    SSR Adjustment Sum  Inactive Withdrawal Sum  Active Withdrawal Sum  \
# 0           -11084934                        0              -43046960
#
#    Active Deposits Sum  Manual Adjustment Sum
# 0              8491968                      0

# %% [markdown]
# The running total of changes by the type of adjustment are as follows, which will result in new adjusted Idle supply

# %%
cumulative_sums = net_change_df.cumsum(axis=1).iloc[-1]
cumulative_sums_df = pd.DataFrame({
    'SSR Adjustment Sum': [cumulative_sums['SSR Adjustment Sum']],
    'Inactive Withdrawal Sum': [cumulative_sums['Inactive Withdrawal Sum']],
    'Active Withdrawal Sum': [cumulative_sums['Active Withdrawal Sum']],
    'Active Deposits Sum': [cumulative_sums['Active Deposits Sum']],
    'Manual Adjustment Sum': [cumulative_sums['Manual Adjustment Sum']]
})
cumulative_sums_df = cumulative_sums_df.round(0).astype(int)

cumulative_sums_df
# Out:
#    SSR Adjustment Sum  Inactive Withdrawal Sum  Active Withdrawal Sum  \
# 0           -11084934                -11084934              -54131894
#
#    Active Deposits Sum  Manual Adjustment Sum
# 0            -45639926              -45639926

# %% [markdown]
# ## Manual Reallocation Dataframe
#
# The following table shows the change and new allocated supply with wei allocation

# %%
new_pool_data = {
    'Net Change': pools_df['Total Change'],
    'New Allocation Supply': pools_df['Final Allocation']
}
manual_realloaction_pools = pd.DataFrame(new_pool_data)
manual_realloaction_pools['New Allocation Wei'] = manual_realloaction_pools['New Allocation Supply'] * pow(10, 18)

# %%
# Create a styled DataFrame
styled_df = manual_realloaction_pools.style.format({
    'Net Change': '{:.0f}',
    'New Allocation Supply': '{:.0f}',
    'New Allocation Wei': '{:.0f}'
}).map(PoolAnalysis.color_net_change, subset=['Net Change'])

styled_df
# Out:
# <style type="text/css">
# #T_ed986_row0_col0, #T_ed986_row3_col0, #T_ed986_row4_col0, #T_ed986_row7_col0, #T_ed986_row8_col0, #T_ed986_row12_col0 {
#   color: black;
# }
# #T_ed986_row1_col0, #T_ed986_row2_col0, #T_ed986_row5_col0, #T_ed986_row6_col0, #T_ed986_row9_col0, #T_ed986_row10_col0 {
#   color: red;
# }
# #T_ed986_row11_col0 {
#   color: green;
# }
# </style>
# <table id="T_ed986">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_ed986_level0_col0" class="col_heading level0 col0" >Net Change</th>
#       <th id="T_ed986_level0_col1" class="col_heading level0 col1" >New Allocation Supply</th>
#       <th id="T_ed986_level0_col2" class="col_heading level0 col2" >New Allocation Wei</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_ed986_level0_row0" class="row_heading level0 row0" >USDe 94.50%</th>
#       <td id="T_ed986_row0_col0" class="data row0 col0" >0</td>
#       <td id="T_ed986_row0_col1" class="data row0 col1" >52032</td>
#       <td id="T_ed986_row0_col2" class="data row0 col2" >52032000000000000000000</td>
#     </tr>
#     <tr>
#       <th id="T_ed986_level0_row1" class="row_heading level0 row1" >USDe 91.50%</th>
#       <td id="T_ed986_row1_col0" class="data row1 col0" >-898456</td>
#       <td id="T_ed986_row1_col1" class="data row1 col1" >21330912</td>
#       <td id="T_ed986_row1_col2" class="data row1 col2" >21330912000000002088763392</td>
#     </tr>
#     <tr>
#       <th id="T_ed986_level0_row2" class="row_heading level0 row2" >USDe 86%</th>
#       <td id="T_ed986_row2_col0" class="data row2 col0" >-6109619</td>
#       <td id="T_ed986_row2_col1" class="data row2 col1" >17073396</td>
#       <td id="T_ed986_row2_col2" class="data row2 col2" >17073395999999999541772288</td>
#     </tr>
#     <tr>
#       <th id="T_ed986_level0_row3" class="row_heading level0 row3" >USDe 77%</th>
#       <td id="T_ed986_row3_col0" class="data row3 col0" >0</td>
#       <td id="T_ed986_row3_col1" class="data row3 col1" >99249</td>
#       <td id="T_ed986_row3_col2" class="data row3 col2" >99248999999999997640704</td>
#     </tr>
#     <tr>
#       <th id="T_ed986_level0_row4" class="row_heading level0 row4" >sUSDe 94.50%</th>
#       <td id="T_ed986_row4_col0" class="data row4 col0" >0</td>
#       <td id="T_ed986_row4_col1" class="data row4 col1" >0</td>
#       <td id="T_ed986_row4_col2" class="data row4 col2" >0</td>
#     </tr>
#     <tr>
#       <th id="T_ed986_level0_row5" class="row_heading level0 row5" >sUSDe 91.50%</th>
#       <td id="T_ed986_row5_col0" class="data row5 col0" >-2111199</td>
#       <td id="T_ed986_row5_col1" class="data row5 col1" >29970204</td>
#       <td id="T_ed986_row5_col2" class="data row5 col2" >29970203999999999279628288</td>
#     </tr>
#     <tr>
#       <th id="T_ed986_level0_row6" class="row_heading level0 row6" >sUSDe 86%</th>
#       <td id="T_ed986_row6_col0" class="data row6 col0" >-1467933</td>
#       <td id="T_ed986_row6_col1" class="data row6 col1" >46288736</td>
#       <td id="T_ed986_row6_col2" class="data row6 col2" >46288735999999997290479616</td>
#     </tr>
#     <tr>
#       <th id="T_ed986_level0_row7" class="row_heading level0 row7" >sUSDe 77%</th>
#       <td id="T_ed986_row7_col0" class="data row7 col0" >0</td>
#       <td id="T_ed986_row7_col1" class="data row7 col1" >75719</td>
#       <td id="T_ed986_row7_col2" class="data row7 col2" >75719000000000004456448</td>
#     </tr>
#     <tr>
#       <th id="T_ed986_level0_row8" class="row_heading level0 row8" >PT-sUSDe-24Oct2024 86%</th>
#       <td id="T_ed986_row8_col0" class="data row8 col0" >0</td>
#       <td id="T_ed986_row8_col1" class="data row8 col1" >71</td>
#       <td id="T_ed986_row8_col2" class="data row8 col2" >71000000000000000000</td>
#     </tr>
#     <tr>
#       <th id="T_ed986_level0_row9" class="row_heading level0 row9" >PT-sUSDe-26Dec2024 91.5%</th>
#       <td id="T_ed986_row9_col0" class="data row9 col0" >-2606917</td>
#       <td id="T_ed986_row9_col1" class="data row9 col1" >351533</td>
#       <td id="T_ed986_row9_col2" class="data row9 col2" >351532999999999990300672</td>
#     </tr>
#     <tr>
#       <th id="T_ed986_level0_row10" class="row_heading level0 row10" >PT-sUSDe-27Mar2025 91.5%</th>
#       <td id="T_ed986_row10_col0" class="data row10 col0" >-40935761</td>
#       <td id="T_ed986_row10_col1" class="data row10 col1" >354350533</td>
#       <td id="T_ed986_row10_col2" class="data row10 col2" >354350533000000023555997696</td>
#     </tr>
#     <tr>
#       <th id="T_ed986_level0_row11" class="row_heading level0 row11" >PT-USDe-27Mar2025 91.5%</th>
#       <td id="T_ed986_row11_col0" class="data row11 col0" >8491969</td>
#       <td id="T_ed986_row11_col1" class="data row11 col1" >83691056</td>
#       <td id="T_ed986_row11_col2" class="data row11 col2" >83691056000000001161822208</td>
#     </tr>
#     <tr>
#       <th id="T_ed986_level0_row12" class="row_heading level0 row12" >PT-sUSDe-29May2025 91.5%</th>
#       <td id="T_ed986_row12_col0" class="data row12 col0" >0</td>
#       <td id="T_ed986_row12_col1" class="data row12 col1" >0</td>
#       <td id="T_ed986_row12_col2" class="data row12 col2" >0</td>
#     </tr>
#   </tbody>
# </table>

# %%
print(f'The total net change in allocation is: ${manual_realloaction_pools["Net Change"].sum():.0f}')
# Out:
# The total net change in allocation is: $-45637916

# %% [markdown]
# ## Pool Overview Dataframe
#
# A brief statistics for pool overview

# %%
pool_stats = [
    'Total Non-Idle Allocation',
    'Supply Weighted LLTV',
    'Supply Weighted sUSDe',
    'Average Borrow Rate',
    'Average Capped Rate',
    'Rate at Prior Equilibrium',
]
columns_stats = [
    'Current',
    'Future',
    'Change'                 
]

pool_overview = pd.DataFrame(index=pool_stats, columns=columns_stats)
statistics = PoolOverview(pools_df, pool_overview)

# %%
statistics.update_pool_overview()
# Out:
#                              Current     Future    Change
# Total Non-Idle Allocation  598921358  553283441 -0.076200
# Supply Weighted LLTV        0.908446   0.908658  0.000234
# Supply Weighted sUSDe        0.13343   0.137967  0.034004
# Average Borrow Rate         0.246245   0.156589 -0.364092
# Average Capped Rate         0.143358   0.151142  0.054296
# Rate at Prior Equilibrium   0.246245   0.156589 -0.364092

# %%
pool_styled_df = pool_overview.style.format({
    'Current': '{:.3f}',
    'Future': '{:.3f}',
    'Change': '{:.2f}%'
}).map(PoolAnalysis.color_net_change, subset=['Change'])

pool_styled_df
# Out:
# <style type="text/css">
# #T_a35ee_row0_col2, #T_a35ee_row3_col2, #T_a35ee_row5_col2 {
#   color: red;
# }
# #T_a35ee_row1_col2, #T_a35ee_row2_col2, #T_a35ee_row4_col2 {
#   color: green;
# }
# </style>
# <table id="T_a35ee">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_a35ee_level0_col0" class="col_heading level0 col0" >Current</th>
#       <th id="T_a35ee_level0_col1" class="col_heading level0 col1" >Future</th>
#       <th id="T_a35ee_level0_col2" class="col_heading level0 col2" >Change</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_a35ee_level0_row0" class="row_heading level0 row0" >Total Non-Idle Allocation</th>
#       <td id="T_a35ee_row0_col0" class="data row0 col0" >598921358.000</td>
#       <td id="T_a35ee_row0_col1" class="data row0 col1" >553283441.000</td>
#       <td id="T_a35ee_row0_col2" class="data row0 col2" >-0.08%</td>
#     </tr>
#     <tr>
#       <th id="T_a35ee_level0_row1" class="row_heading level0 row1" >Supply Weighted LLTV</th>
#       <td id="T_a35ee_row1_col0" class="data row1 col0" >0.908</td>
#       <td id="T_a35ee_row1_col1" class="data row1 col1" >0.909</td>
#       <td id="T_a35ee_row1_col2" class="data row1 col2" >0.00%</td>
#     </tr>
#     <tr>
#       <th id="T_a35ee_level0_row2" class="row_heading level0 row2" >Supply Weighted sUSDe</th>
#       <td id="T_a35ee_row2_col0" class="data row2 col0" >0.133</td>
#       <td id="T_a35ee_row2_col1" class="data row2 col1" >0.138</td>
#       <td id="T_a35ee_row2_col2" class="data row2 col2" >0.03%</td>
#     </tr>
#     <tr>
#       <th id="T_a35ee_level0_row3" class="row_heading level0 row3" >Average Borrow Rate</th>
#       <td id="T_a35ee_row3_col0" class="data row3 col0" >0.246</td>
#       <td id="T_a35ee_row3_col1" class="data row3 col1" >0.157</td>
#       <td id="T_a35ee_row3_col2" class="data row3 col2" >-0.36%</td>
#     </tr>
#     <tr>
#       <th id="T_a35ee_level0_row4" class="row_heading level0 row4" >Average Capped Rate</th>
#       <td id="T_a35ee_row4_col0" class="data row4 col0" >0.143</td>
#       <td id="T_a35ee_row4_col1" class="data row4 col1" >0.151</td>
#       <td id="T_a35ee_row4_col2" class="data row4 col2" >0.05%</td>
#     </tr>
#     <tr>
#       <th id="T_a35ee_level0_row5" class="row_heading level0 row5" >Rate at Prior Equilibrium</th>
#       <td id="T_a35ee_row5_col0" class="data row5 col0" >0.246</td>
#       <td id="T_a35ee_row5_col1" class="data row5 col1" >0.157</td>
#       <td id="T_a35ee_row5_col2" class="data row5 col2" >-0.36%</td>
#     </tr>
#   </tbody>
# </table>

# %% [markdown]
# ### Current Debt Ceiling

# %%
current_ddm_target_debt = int(pool_overview.at['Total Non-Idle Allocation', 'Current'] + idle_df.at['Idle', 'Total Supply'])

print(f'The current DDM target debt is: ${current_ddm_target_debt}')

future_ddm_target_debt = math.ceil((int(pool_overview.at['Total Non-Idle Allocation', 'Future'])+ 5000000)/ 25000000) * 25000000

print(f'The future DDM target debt is: ${future_ddm_target_debt}')
# Out:
# The current DDM target debt is: $626587251
# The future DDM target debt is: $575000000

# %% [markdown]
# ## JSON Logic
#
# Include only pools that change in allocation
#
# ### Allocation to USDe
#
# [
# MakerDAO: Dai Token (DAI),
# Ethena: USDe (USDe),
# Morpho: MorphoChainlinkOracleV2,
# Morpho: AdaptiveCurveIRM,
# LLTV (times 10E16)
# ],
# Allocation WEI
#
# ### Allocation to sUSDe
#
# [
# MakerDAO: Dai Token (DAI),
# Ethena: Staked USDe (sUSDe),
# Morpho: MorphoChainlinkOracleV2,
# Morpho: AdaptiveCurveIRM,
# LLTV (times 10E16)
# ]
# Allocation WEI
#
# ### Everything else goes to the idle market
#
# [
# MakerDAO: Dai Token (DAI),
# Burn Address,
# Burn Address,
# Burn Address,
# 0
# ]
# Uint256 Maximum Value

# %%
manual_reallocation_pools = manual_realloaction_pools

manual_reallocation_pools.index = [
    'USDe 94.50%', 'USDe 91.50%', 'USDe 86%', 'USDe 77%', 
    'sUSDe 94.50%', 'sUSDe 91.50%', 'sUSDe 86%', 'sUSDe 77%', 
    'PT-sUSDe-24Oct2024 86%', 'PT-sUSDe-26Dec2024 91.5%', 'PT-sUSDe-27Mar2025 91.5%',
    'PT-USDe-27Mar2025 91.5%', 'PT-sUSDe-29May2025 91.5%'

]

# Define the base address values - Source: https://docs.morpho.org/addresses/
base_addresses = {
    "USDe": [
        "0x6B175474E89094C44Da98b954EedeAC495271d0F", # DAI
        "0x4c9EDD5852cd905f086C759E8383e09bff1E68B3", # USDe
        "0xaE4750d0813B5E37A51f7629beedd72AF1f9cA35", # MorphoChainlinkOracleV2
        "0x870aC11D48B15DB9a138Cf899d20F13F79Ba00BC" # AdaptiveCurveIRM
    ],
    "sUSDe": [
        "0x6B175474E89094C44Da98b954EedeAC495271d0F", # DAI
        "0x9D39A5DE30e57443BfF2A8307A4256c8797A3497", # sUSDe
        "0x5D916980D5Ae1737a8330Bf24dF812b2911Aae25", # MorphoChainlinkOracleV2
        "0x870aC11D48B15DB9a138Cf899d20F13F79Ba00BC" # AdaptiveCurveIRM
    ],
    "PT-sUSDe-24Oct2024": [
        "0x6B175474E89094C44Da98b954EedeAC495271d0F", # DAI
        "0xAE5099C39f023C91d3dd55244CAFB36225B0850E", # PT-sUSDe-24Oct2024
        "0xaE4750d0813B5E37A51f7629beedd72AF1f9cA35", # MorphoChainlinkOracleV2
        "0x870aC11D48B15DB9a138Cf899d20F13F79Ba00BC" # AdaptiveCurveIRM
    ],
    "PT-sUSDe-26Dec2024": [
        "0x6B175474E89094C44Da98b954EedeAC495271d0F", # DAI
        "0xEe9085fC268F6727d5D4293dBABccF901ffDCC29", # PT-sUSDe-26Dec2024
        "0x81E5E28F33D314e9211885d6f0F4080E755e4595", # MorphoChainlinkOracleV2
        "0x870aC11D48B15DB9a138Cf899d20F13F79Ba00BC" # AdaptiveCurveIRM
    ],
    "PT-sUSDe-27Mar2025": [
        "0x6B175474E89094C44Da98b954EedeAC495271d0F", # DAI
        "0xe00bd3df25fb187d6abbb620b3dfd19839947b81", # PT-sUSDe-27Mar2025
        "0x38d130cEe60CDa080A3b3aC94C79c34B6Fc919A7", # MorphoChainlinkOracleV2
        "0x870aC11D48B15DB9a138Cf899d20F13F79Ba00BC" # AdaptiveCurveIRM
    ],
    "PT-USDe-27Mar2025": [
        "0x6B175474E89094C44Da98b954EedeAC495271d0F", # DAI
        "0x8a47b431a7d947c6a3ed6e42d501803615a97eaa", # PT-USDe-27Mar2025
        "0xA8ccE51046d760291f77eC1EB98147A75730Dcd5", # MorphoChainlinkOracleV2
        "0x870aC11D48B15DB9a138Cf899d20F13F79Ba00BC" # AdaptiveCurveIRM
    ],
    "PT-sUSDe-29May2025": [
        "0x6B175474E89094C44Da98b954EedeAC495271d0F", # DAI
        "0xb7de5dfcb74d25c2f21841fbd6230355c50d9308", # PT-sUSDe-29May2025
        "0xe84f7e0a890e5e57d0beea2c8716ddf0c9846b4a", # MorphoChainlinkOracleV2
        "0x870aC11D48B15DB9a138Cf899d20F13F79Ba00BC" # AdaptiveCurveIRM
    ],
    "Idle": [
        "0x6B175474E89094C44Da98b954EedeAC495271d0F", # DAI
        "0x0000000000000000000000000000000000000000", # Idle
        "0x0000000000000000000000000000000000000000", # MorphoChainlinkOracleV2
        "0x0000000000000000000000000000000000000000" # AdaptiveCurveIRM
    ]
}

#pools_df.loc['PT-USDe-27Mar2025 91.5%', 'Manual Adjustment'] = int(0)
#pools_df.loc['PT-sUSDe-29May2025 91.5%', 'Manual Adjustment'] = int(0)

# Function to determine the pool type based on the allocation type (in the index)
def determine_pool_type(allocation_type):
    # Extract the part before the percentage
    asset_type = allocation_type.split()[0]  # Gets "USDe", "sUSDe", or "PT-sUSDe-24Oct2024"
    
    if asset_type == "USDe":
        return base_addresses["USDe"]
    elif asset_type == "sUSDe":
        return base_addresses["sUSDe"]
    elif asset_type == "PT-sUSDe-24Oct2024":
        return base_addresses["PT-sUSDe-24Oct2024"]
    elif asset_type == "PT-sUSDe-26Dec2024":
        return base_addresses["PT-sUSDe-26Dec2024"]
    elif asset_type == "PT-sUSDe-27Mar2025":
        return base_addresses["PT-sUSDe-27Mar2025"]
    elif asset_type == "PT-USDe-27Mar2025":
        return base_addresses["PT-USDe-27Mar2025"]
    elif asset_type == "PT-sUSDe-29May2025":
        return base_addresses["PT-sUSDe-29May2025"]
    else:
        return base_addresses["Idle"]

# Initialize the JSON structure
output_json = []

for allocation_type, row in manual_reallocation_pools.iterrows():
    if row['Net Change'] != 0:
        pool_type = determine_pool_type(allocation_type)
        lltv = str(int(float(allocation_type.split()[1].replace('%', '')) * 10**16))  # Convert percentage to LLTV
        pool = pool_type + [lltv]

        allocation_wei = str(row['New Allocation Wei'])  # Convert to string
        
        output_json.append([pool, allocation_wei])

# Add the 'Idle' pool entry
idle_pool = base_addresses["Idle"] + ["0"]
idle_allocation_wei = "0xffffffffffffffffffffffffffffffffffffffffffffffffffffffffffffffff"
output_json.append([idle_pool, idle_allocation_wei])

# Convert the list to JSON formatted string
output_str = json.dumps(output_json, indent=2)

# Print or save the JSON formatted string
print(output_str)

# Optionally, save to a file
with open("morpho_vault_realloc.json", "w") as file:
    file.write(output_str)
# Out:
# [
#   [
#     [
#       "0x6B175474E89094C44Da98b954EedeAC495271d0F",
#       "0x4c9EDD5852cd905f086C759E8383e09bff1E68B3",
#       "0xaE4750d0813B5E37A51f7629beedd72AF1f9cA35",
#       "0x870aC11D48B15DB9a138Cf899d20F13F79Ba00BC",
#       "915000000000000000"
#     ],
#     "21330912000000000000000000"
#   ],
#   [
#     [
#       "0x6B175474E89094C44Da98b954EedeAC495271d0F",
#       "0x4c9EDD5852cd905f086C759E8383e09bff1E68B3",
#       "0xaE4750d0813B5E37A51f7629beedd72AF1f9cA35",
#       "0x870aC11D48B15DB9a138Cf899d20F13F79Ba00BC",
#       "860000000000000000"
#     ],
#     "17073396000000000000000000"
#   ],
#   [
#     [
#       "0x6B175474E89094C44Da98b954EedeAC495271d0F",
#       "0x9D39A5DE30e57443BfF2A8307A4256c8797A3497",
#       "0x5D916980D5Ae1737a8330Bf24dF812b2911Aae25",
#       "0x870aC11D48B15DB9a138Cf899d20F13F79Ba00BC",
#       "915000000000000000"
#     ],
#     "29970204000000000000000000"
#   ],
#   [
#     [
#       "0x6B175474E89094C44Da98b954EedeAC495271d0F",
#       "0x9D39A5DE30e57443BfF2A8307A4256c8797A3497",
#       "0x5D916980D5Ae1737a8330Bf24dF812b2911Aae25",
#       "0x870aC11D48B15DB9a138Cf899d20F13F79Ba00BC",
#       "860000000000000000"
#     ],
#     "46288736000000000000000000"
#   ],
#   [
#     [
#       "0x6B175474E89094C44Da98b954EedeAC495271d0F",
#       "0xEe9085fC268F6727d5D4293dBABccF901ffDCC29",
#       "0x81E5E28F33D314e9211885d6f0F4080E755e4595",
#       "0x870aC11D48B15DB9a138Cf899d20F13F79Ba00BC",
#       "915000000000000000"
#     ],
#     "351533000000000000000000"
#   ],
#   [
#     [
#       "0x6B175474E89094C44Da98b954EedeAC495271d0F",
#       "0xe00bd3df25fb187d6abbb620b3dfd19839947b81",
#       "0x38d130cEe60CDa080A3b3aC94C79c34B6Fc919A7",
#       "0x870aC11D48B15DB9a138Cf899d20F13F79Ba00BC",
#       "915000000000000000"
#     ],
#     "354350533000000000000000000"
#   ],
#   [
#     [
#       "0x6B175474E89094C44Da98b954EedeAC495271d0F",
#       "0x8a47b431a7d947c6a3ed6e42d501803615a97eaa",
#       "0xA8ccE51046d760291f77eC1EB98147A75730Dcd5",
#       "0x870aC11D48B15DB9a138Cf899d20F13F79Ba00BC",
#       "915000000000000000"
#     ],
#     "83691056000000000000000000"
#   ],
#   [
#     [
#       "0x6B175474E89094C44Da98b954EedeAC495271d0F",
#       "0x0000000000000000000000000000000000000000",
#       "0x0000000000000000000000000000000000000000",
#       "0x0000000000000000000000000000000000000000",
#       "0"
#     ],
#     "0xffffffffffffffffffffffffffffffffffffffffffffffffffffffffffffffff"
#   ]
# ]

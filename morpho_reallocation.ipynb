# %% [markdown]
# # USDe Morpho Benchmarks and Reallocation
#
# In this Jupyter notebook, we will automate the process of analyzing and reallocating USDe liquidity within Morpho's financial pools.
#
# Our primary focus will lie in assessing the current allocation of USDe, the utilization rates, borrowing rates, optimal rates, and capped rates across different liquidity pools distinguished by their Loan-to-Value (LTV) ratios. We aim to ensure that pool allocations are optimized both for the stable functioning of the overall market and for better returns for liquidity providers and borrowers.
#
# 1. **Data Analysis**: We will start by performing a data analysis on the current status of various USDe pools. This will include processing important metrics such as total supply, borrow rates, and optimal rates to identify pools that may require attention or reallocation.
#
# 2. **Manual Reallocation Criteria**: Based on the analysis, we'll assess the necessity for manual reallocations in accordance with established criteria for active and inactive pools, including factors like minimum balances, maximum utilization, and the safety margin for withdrawing portions of the allocated USDe supply.

# %%
import pandas as pd
import numpy as np
import datetime
from data_manipulation import *
from api import *

pd.set_option('display.max_columns', None)

# %% [markdown]
# ## Manual Reallocation Analysis
#
# Defined Pools we look at for allocation and necessary values

# %%
pool_keys = [
    'USDe 94.50%',
    'USDe 91.50%',
    'USDe 86%',
    'USDe 77%',
    'sUSDe 94.50%',
    'sUSDe 91.50%',
    'sUSDe 86%',
    'sUSDe 77%'
]
idle_key = [
    'Idle',
]
idle_col = [
    'LLTV',
    'Total Supply', 
    'Maker Allocation',     
    'Utilization', 
    'Borrow Rate',              
]
columns_ordered = [
    'Status', 
    'LLTV',
    'Total Supply', 
    'Maker Allocation', 
    'Utilization', 
    'Borrow Rate', 
    'Total Borrow', 
    'Maker Borrow', 
    'Optimal Rate', 
    'Capped Borrow Rate', 
    'Inactive Adjustment', 
    'Active Adjustment', 
    'Manual Adjustment',
    'Total Change',
    'Final Allocation',
    'Final Supply',
    'Final Utilization',
    'Final Borrow Rate',
    'Final Capped Rate',
    'Maker Borrow at Old Utilization',
    'Borrow Rate Change',                   
]

pools_df = pd.DataFrame(index=pool_keys, columns=columns_ordered)
idle_df = pd.DataFrame(index=idle_key, columns=idle_col)
pools_df.head(1)
# Out:
#             Status LLTV Total Supply Maker Allocation Utilization Borrow Rate  \
# USDe 94.50%    NaN  NaN          NaN              NaN         NaN         NaN
#
#             Total Borrow Maker Borrow Optimal Rate Capped Borrow Rate  \
# USDe 94.50%          NaN          NaN          NaN                NaN
#
#             Inactive Adjustment Active Adjustment Manual Adjustment  \
# USDe 94.50%                 NaN               NaN               NaN
#
#             Total Change Final Allocation Final Supply Final Utilization  \
# USDe 94.50%          NaN              NaN          NaN               NaN
#
#             Final Borrow Rate Final Capped Rate  \
# USDe 94.50%               NaN               NaN
#
#             Maker Borrow at Old Utilization Borrow Rate Change
# USDe 94.50%                             NaN                NaN

# %%
idle_df
# Out:
#      LLTV Total Supply Maker Allocation Utilization Borrow Rate
# Idle  NaN          NaN              NaN         NaN         NaN

# %% [markdown]
# ### Retrieve latest values
#
# Connect to BA API and retrieve the data for the pools we are interested in. First define pools by their uuid, to retrieve the data.

# %%
market_to_pool = {
    "db760246f6859780f6c1b272d47a8f64710777121118e56e0cdb4b8b744a3094": 'USDe 94.50%',
    "8e6aeb10c401de3279ac79b4b2ea15fc94b7d9cfc098d6c2a1ff7b2b26d9d02c": 'USDe 91.50%',
    "c581c5f70bd1afa283eed57d1418c6432cbff1d862f94eaf58fdd4e46afbb67f": 'USDe 86%',
    "fd8493f09eb6203615221378d89f53fcd92ff4f7d62cca87eece9a2fff59e86f": 'USDe 77%',
    "e475337d11be1db07f7c5a156e511f05d1844308e66e17d2ba5da0839d3b34d9": 'sUSDe 94.50%',
    "1247f1c237eceae0602eab1470a5061a6dd8f734ba88c7cdc5d6109fb0026b28": 'sUSDe 91.50%',
    "39d11026eae1c6ec02aa4c0910778664089cdd97c3fd23f68f7cd05e2e95af48": 'sUSDe 86%',
    "42dcfb38bb98767afb6e38ccf90d59d0d3f0aa216beb3a234f12850323d17536": 'sUSDe 77%'
}

# %%
# market_to_pool.keys()

# %% [markdown]
# Retrieve the data from API

# %%
# Base URL for market data
base_market_url = "https://morpho-api.blockanalitica.com/markets/{}/historic/?days_ago=0&network=ethereum"
# Base URL for wallet data
base_wallet_url = "https://morpho-api.blockanalitica.com/markets/{}/wallets/?network=ethereum&order=-supply&p_size=4&type=suppliers"
# The wallet address we are interested in
target_wallet = "0x73e65dbd630f90604062f6e02fab9138e713edd9"

api_data = ApiBA(base_market_url, base_wallet_url, market_to_pool.keys(), target_wallet)

# %% [markdown]
# With data from API populate the dataframe

# %%
market_data = PoolDataHandler(pools_df, market_to_pool)
pools_df = market_data.populate_dataframe(api_data.fetch_data())
pools_df
# Out:
# Updated DataFrame:
#              Status   LLTV Total Supply Maker Allocation Utilization  \
# USDe 94.50%     NaN  0.945      1128767           954380        0.93
# USDe 91.50%     NaN  0.915     54686492         50954096      0.8994
# USDe 86%        NaN   0.86     98293119         98293119      0.9001
# USDe 77%        NaN   0.77      7202619          7202619      0.9171
# sUSDe 94.50%    NaN  0.945      1971526          1600453      0.8746
# sUSDe 91.50%    NaN  0.915     79437762         79437762      0.9013
# sUSDe 86%       NaN   0.86    146412080        146411980      0.9082
# sUSDe 77%       NaN   0.77       135519           110058      0.2382
#
#              Borrow Rate Total Borrow Maker Borrow Optimal Rate  \
# USDe 94.50%       0.1797          NaN          NaN          NaN
# USDe 91.50%       0.1021          NaN          NaN          NaN
# USDe 86%          0.0984          NaN          NaN          NaN
# USDe 77%          0.1351          NaN          NaN          NaN
# sUSDe 94.50%      0.0939          NaN          NaN          NaN
# sUSDe 91.50%      0.1034          NaN          NaN          NaN
# sUSDe 86%          0.133          NaN          NaN          NaN
# sUSDe 77%         0.0212          NaN          NaN          NaN
#
#              Capped Borrow Rate Inactive Adjustment Active Adjustment  \
# USDe 94.50%                 NaN                 NaN               NaN
# USDe 91.50%                 NaN                 NaN               NaN
# USDe 86%                    NaN                 NaN               NaN
# USDe 77%                    NaN                 NaN               NaN
# sUSDe 94.50%                NaN                 NaN               NaN
# sUSDe 91.50%                NaN                 NaN               NaN
# sUSDe 86%                   NaN                 NaN               NaN
# sUSDe 77%                   NaN                 NaN               NaN
#
#              Manual Adjustment Total Change Final Allocation Final Supply  \
# USDe 94.50%                NaN          NaN              NaN          NaN
# USDe 91.50%                NaN          NaN              NaN          NaN
# USDe 86%                   NaN          NaN              NaN          NaN
# USDe 77%                   NaN          NaN              NaN          NaN
# sUSDe 94.50%               NaN          NaN              NaN          NaN
# sUSDe 91.50%               NaN          NaN              NaN          NaN
# sUSDe 86%                  NaN          NaN              NaN          NaN
# sUSDe 77%                  NaN          NaN              NaN          NaN
#
#              Final Utilization Final Borrow Rate Final Capped Rate  \
# USDe 94.50%                NaN               NaN               NaN
# USDe 91.50%                NaN               NaN               NaN
# USDe 86%                   NaN               NaN               NaN
# USDe 77%                   NaN               NaN               NaN
# sUSDe 94.50%               NaN               NaN               NaN
# sUSDe 91.50%               NaN               NaN               NaN
# sUSDe 86%                  NaN               NaN               NaN
# sUSDe 77%                  NaN               NaN               NaN
#
#              Maker Borrow at Old Utilization Borrow Rate Change
# USDe 94.50%                              NaN                NaN
# USDe 91.50%                              NaN                NaN
# USDe 86%                                 NaN                NaN
# USDe 77%                                 NaN                NaN
# sUSDe 94.50%                             NaN                NaN
# sUSDe 91.50%                             NaN                NaN
# sUSDe 86%                                NaN                NaN
# sUSDe 77%                                NaN                NaN

# %% [markdown]
# To see the allocation in the Idle matket:

# %%
idle_market_to_pool = {"57f4e42c0707d3ae0ae39c9343dcba78ff79fa663da040eca45717a9b0b0557f": 'Idle'}
idle_api_data = ApiBA(base_market_url, base_wallet_url, idle_market_to_pool.keys(), target_wallet)
idle_data = PoolDataHandler(idle_df, idle_market_to_pool)
idle_df = idle_data.populate_dataframe(idle_api_data.fetch_data())
idle_df
# Out:
# Updated DataFrame:
#      LLTV Total Supply Maker Allocation Utilization Borrow Rate
# Idle  0.0     65112702         65112702         0.0         0.0

# %% [markdown]
# ### Reallocation Metaparameters
#
# They are set as done by Monet. Change only in case you know what you are doing!

# %%
realloc_metaparm = {
    'active_pool' : {
        'min_balance' : 10000000,
        'max_utilization' : 0.9,
        'max_portion_to_withdraw' : 0.1,
    },
    'inactive_pool' : {
        'min_balance' : 100000,
        'max_utilization' : 0.93,
        'max_portion_to_withdraw' : 1,
    },
}

# %%
pools_analysis = PoolAnalysis(pools_df, realloc_metaparm)

# %% [markdown]
# #### Classify market as Active or Inactive
#
# In the dropdown, select whether the market mentioned should be Active or Inactive by typing in the above cell.
# In a case you defined some of the values wrong, update them with this code:
# `pools_df.loc['pool name', 'column name'] = 'new value'`

# %%
# pools_df.loc[pool_key, 'Status'] = 'Active'

# %%
pools_analysis.define_active_or_inactive()
# Out:
# Please enter 'Active' or 'Inactive' for each market:
#
# Updated DataFrame with Status:

# %% [markdown]
# ### Reallocation Dataframe
#
# Get the final table with all data. For easier overview focus on the following tables

# %%
pools_analysis = PoolAnalysis(pools_df, realloc_metaparm)

# %%
pools_analysis.update_pool_dataframe()
# Out:
#                 Status   LLTV Total Supply Maker Allocation Utilization  \
# USDe 94.50%   Inactive  0.945      1128767           954380        0.93
# USDe 91.50%     Active  0.915     54686492         50954096      0.8994
# USDe 86%        Active   0.86     98293119         98293119      0.9001
# USDe 77%      Inactive   0.77      7202619          7202619      0.9171
# sUSDe 94.50%  Inactive  0.945      1971526          1600453      0.8746
# sUSDe 91.50%    Active  0.915     79437762         79437762      0.9013
# sUSDe 86%       Active   0.86    146412080        146411980      0.9082
# sUSDe 77%     Inactive   0.77       135519           110058      0.2382
#
#              Borrow Rate Total Borrow Maker Borrow Optimal Rate  \
# USDe 94.50%       0.1797      1049753       887573       0.0946
# USDe 91.50%       0.1021     49185030     45828113       0.1022
# USDe 86%          0.0984     88473636     88473636       0.0981
# USDe 77%          0.1351      6605521      6605521       0.0893
# sUSDe 94.50%      0.0939      1724296      1399755       0.0959
# sUSDe 91.50%      0.1034     71597254     71597254       0.0995
# sUSDe 86%          0.133    132971451    132971360       0.1067
# sUSDe 77%         0.0212        32280        26215       0.0473
#
#              Capped Borrow Rate Inactive Adjustment Active Adjustment  \
# USDe 94.50%              0.0946                   0                 0
# USDe 91.50%              0.1021                   0            -36458
# USDe 86%                 0.0981                   0                 0
# USDe 77%                 0.0893              -99908                 0
# sUSDe 94.50%             0.0939             -117444                 0
# sUSDe 91.50%             0.0995                   0                 0
# sUSDe 86%                0.1067                   0                 0
# sUSDe 77%                0.0212              -35519                 0
#
#              Manual Adjustment Total Change Final Allocation Final Supply  \
# USDe 94.50%                  0            0           954380      1128767
# USDe 91.50%                  0       -36458         50917638     54650034
# USDe 86%                     0            0         98293119     98293119
# USDe 77%                     0       -99908          7102711      7102711
# sUSDe 94.50%                 0      -117444          1483009      1854082
# sUSDe 91.50%                 0            0         79437762     79437762
# sUSDe 86%                    0            0        146411980    146412080
# sUSDe 77%                    0       -35519            74539       100000
#
#              Final Utilization Final Borrow Rate Final Capped Rate  \
# USDe 94.50%               0.93            0.1797            0.0946
# USDe 91.50%                0.9            0.1022            0.1022
# USDe 86%                0.9001            0.0984            0.0981
# USDe 77%                  0.93            0.1697            0.0893
# sUSDe 94.50%              0.93            0.1822            0.0959
# sUSDe 91.50%            0.9013            0.1034            0.0995
# sUSDe 86%               0.9082            0.1329            0.1067
# sUSDe 77%               0.3228            0.0245            0.0245
#
#              Maker Borrow at Old Utilization Borrow Rate Change
# USDe 94.50%                           887573                0.0
# USDe 91.50%                         45795323             0.0001
# USDe 86%                            88473636                0.0
# USDe 77%                             6513896             0.0346
# sUSDe 94.50%                         1297039             0.0883
# sUSDe 91.50%                        71597254                0.0
# sUSDe 86%                          132971360            -0.0001
# sUSDe 77%                              17755             0.0033

# %% [markdown]
# Save the data if you want to perform later analysis or visualizations on this

# %%
# pools_analysis.pool_df.to_json(f'reallocations_{datetime.datetime.now().strftime('%Y_%m_%d')}.json')

# %% [markdown]
# ### Average Utilization, Net and Running Change
#
# Some basic statistics for reallocation

# %%
average_utilization = pools_analysis.pool_df['Utilization'].mean()
print(f'The average utilization of the pools is: {average_utilization * 100:.2f}%')
# Out:
# The average utilization of the pools is: 82.11%

# %% [markdown]
# The net changes based on the type of adjusment are as follows

# %%
net_change_df = pools_analysis.pool_df[['Inactive Adjustment', 'Active Adjustment', 'Manual Adjustment']].agg('sum').to_frame().T
net_change_df.columns = ['Inactive Adjustment Sum', 'Active Adjustment Sum', 'Manual Adjustment Sum']
net_change_df = net_change_df.round(0).astype(int)

net_change_df
# Out:
#    Inactive Adjustment Sum  Active Adjustment Sum  Manual Adjustment Sum
# 0                  -252871                 -36458                      0

# %% [markdown]
# The running total of changes by the type of adjustment are as follows, which will result in new adjusted Idle supply

# %%
cumulative_sums = net_change_df.cumsum(axis=1).iloc[-1]
cumulative_sums_df = pd.DataFrame({
    'Inactive Sum': [cumulative_sums['Inactive Adjustment Sum']],
    'Inactive + Active Sum': [cumulative_sums['Active Adjustment Sum']],
    'Inactive + Active + Manual Sum': [cumulative_sums['Manual Adjustment Sum']]
})
cumulative_sums_df = cumulative_sums_df.round(0).astype(int)

cumulative_sums_df
# Out:
#    Inactive Sum  Inactive + Active Sum  Inactive + Active + Manual Sum
# 0       -252871                -289329                         -289329

# %% [markdown]
# ## Manual Reallocation Dataframe
#
# The following table shows the change and new allocated supply with wei allocation

# %%
new_pool_data = {
    'Net Change': pools_df['Total Change'],
    'New Allocation Supply': pools_df['Final Allocation']
}
manual_realloaction_pools = pd.DataFrame(new_pool_data)
manual_realloaction_pools['New Allocation Wei'] = manual_realloaction_pools['New Allocation Supply'] * pow(10, 18)

# %%
# Create a styled DataFrame
styled_df = manual_realloaction_pools.style.format({
    'Net Change': '{:.0f}',
    'New Allocation Supply': '{:.0f}',
    'New Allocation Wei': '{:.0f}'
}).map(PoolAnalysis.color_net_change, subset=['Net Change'])

styled_df
# Out:
# <style type="text/css">
# #T_ef24c_row0_col0, #T_ef24c_row2_col0, #T_ef24c_row5_col0, #T_ef24c_row6_col0 {
#   color: black;
# }
# #T_ef24c_row1_col0, #T_ef24c_row3_col0, #T_ef24c_row4_col0, #T_ef24c_row7_col0 {
#   color: red;
# }
# </style>
# <table id="T_ef24c">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_ef24c_level0_col0" class="col_heading level0 col0" >Net Change</th>
#       <th id="T_ef24c_level0_col1" class="col_heading level0 col1" >New Allocation Supply</th>
#       <th id="T_ef24c_level0_col2" class="col_heading level0 col2" >New Allocation Wei</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_ef24c_level0_row0" class="row_heading level0 row0" >USDe 94.50%</th>
#       <td id="T_ef24c_row0_col0" class="data row0 col0" >0</td>
#       <td id="T_ef24c_row0_col1" class="data row0 col1" >954380</td>
#       <td id="T_ef24c_row0_col2" class="data row0 col2" >954379999999999988465664</td>
#     </tr>
#     <tr>
#       <th id="T_ef24c_level0_row1" class="row_heading level0 row1" >USDe 91.50%</th>
#       <td id="T_ef24c_row1_col0" class="data row1 col0" >-36458</td>
#       <td id="T_ef24c_row1_col1" class="data row1 col1" >50917638</td>
#       <td id="T_ef24c_row1_col2" class="data row1 col2" >50917638000000004020764672</td>
#     </tr>
#     <tr>
#       <th id="T_ef24c_level0_row2" class="row_heading level0 row2" >USDe 86%</th>
#       <td id="T_ef24c_row2_col0" class="data row2 col0" >0</td>
#       <td id="T_ef24c_row2_col1" class="data row2 col1" >98293119</td>
#       <td id="T_ef24c_row2_col2" class="data row2 col2" >98293119000000007539523584</td>
#     </tr>
#     <tr>
#       <th id="T_ef24c_level0_row3" class="row_heading level0 row3" >USDe 77%</th>
#       <td id="T_ef24c_row3_col0" class="data row3 col0" >-99908</td>
#       <td id="T_ef24c_row3_col1" class="data row3 col1" >7102711</td>
#       <td id="T_ef24c_row3_col2" class="data row3 col2" >7102710999999999975096320</td>
#     </tr>
#     <tr>
#       <th id="T_ef24c_level0_row4" class="row_heading level0 row4" >sUSDe 94.50%</th>
#       <td id="T_ef24c_row4_col0" class="data row4 col0" >-117444</td>
#       <td id="T_ef24c_row4_col1" class="data row4 col1" >1483009</td>
#       <td id="T_ef24c_row4_col2" class="data row4 col2" >1483009000000000077332480</td>
#     </tr>
#     <tr>
#       <th id="T_ef24c_level0_row5" class="row_heading level0 row5" >sUSDe 91.50%</th>
#       <td id="T_ef24c_row5_col0" class="data row5 col0" >0</td>
#       <td id="T_ef24c_row5_col1" class="data row5 col1" >79437762</td>
#       <td id="T_ef24c_row5_col2" class="data row5 col2" >79437761999999991581507584</td>
#     </tr>
#     <tr>
#       <th id="T_ef24c_level0_row6" class="row_heading level0 row6" >sUSDe 86%</th>
#       <td id="T_ef24c_row6_col0" class="data row6 col0" >0</td>
#       <td id="T_ef24c_row6_col1" class="data row6 col1" >146411980</td>
#       <td id="T_ef24c_row6_col2" class="data row6 col2" >146411980000000004165992448</td>
#     </tr>
#     <tr>
#       <th id="T_ef24c_level0_row7" class="row_heading level0 row7" >sUSDe 77%</th>
#       <td id="T_ef24c_row7_col0" class="data row7 col0" >-35519</td>
#       <td id="T_ef24c_row7_col1" class="data row7 col1" >74539</td>
#       <td id="T_ef24c_row7_col2" class="data row7 col2" >74539000000000003407872</td>
#     </tr>
#   </tbody>
# </table>

# %%
print(f'The total net change in allocation is: ${manual_realloaction_pools["Net Change"].sum():.0f}')
# Out:
# The total net change in allocation is: $-289329

# %% [markdown]
# ## Pool Overview Dataframe
#
# A brief statistics for pool overview

# %%
pool_stats = [
    'Total Non-Idle Allocation',
    'Supply Weighted LLTV',
    'Supply Weighted sUSDe',
    'Average Borrow Rate',
    'Average Capped Rate',
    'Rate at Prior Equilibrium',
]
columns_stats = [
    'Current',
    'Future',
    'Change'                 
]

pool_overview = pd.DataFrame(index=pool_stats, columns=columns_stats)
statistics = PoolOverview(pools_df, pool_overview)

# %%
stats = statistics.update_pool_overview()

# %%
styled_df = stats.pool_overview.style.format({
    'Current': '{:.3f}',
    'Future': '{:.3f}',
    'Change': '{:.2f}%'
}).map(PoolAnalysis.color_net_change, subset=['Change'])

styled_df
# Out:
# <style type="text/css">
# #T_70e14_row0_col2 {
#   color: red;
# }
# #T_70e14_row1_col2, #T_70e14_row2_col2, #T_70e14_row3_col2, #T_70e14_row4_col2, #T_70e14_row5_col2 {
#   color: green;
# }
# </style>
# <table id="T_70e14">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_70e14_level0_col0" class="col_heading level0 col0" >Current</th>
#       <th id="T_70e14_level0_col1" class="col_heading level0 col1" >Future</th>
#       <th id="T_70e14_level0_col2" class="col_heading level0 col2" >Change</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_70e14_level0_row0" class="row_heading level0 row0" >Total Non-Idle Allocation</th>
#       <td id="T_70e14_row0_col0" class="data row0 col0" >384964467.000</td>
#       <td id="T_70e14_row0_col1" class="data row0 col1" >384675138.000</td>
#       <td id="T_70e14_row0_col2" class="data row0 col2" >-0.00%</td>
#     </tr>
#     <tr>
#       <th id="T_70e14_level0_row1" class="row_heading level0 row1" >Supply Weighted LLTV</th>
#       <td id="T_70e14_row1_col0" class="data row1 col0" >0.877</td>
#       <td id="T_70e14_row1_col1" class="data row1 col1" >0.877</td>
#       <td id="T_70e14_row1_col2" class="data row1 col2" >0.00%</td>
#     </tr>
#     <tr>
#       <th id="T_70e14_level0_row2" class="row_heading level0 row2" >Supply Weighted sUSDe</th>
#       <td id="T_70e14_row2_col0" class="data row2 col0" >0.591</td>
#       <td id="T_70e14_row2_col1" class="data row2 col1" >0.591</td>
#       <td id="T_70e14_row2_col2" class="data row2 col2" >0.00%</td>
#     </tr>
#     <tr>
#       <th id="T_70e14_level0_row3" class="row_heading level0 row3" >Average Borrow Rate</th>
#       <td id="T_70e14_row3_col0" class="data row3 col0" >0.114</td>
#       <td id="T_70e14_row3_col1" class="data row3 col1" >0.115</td>
#       <td id="T_70e14_row3_col2" class="data row3 col2" >0.01%</td>
#     </tr>
#     <tr>
#       <th id="T_70e14_level0_row4" class="row_heading level0 row4" >Average Capped Rate</th>
#       <td id="T_70e14_row4_col0" class="data row4 col0" >0.102</td>
#       <td id="T_70e14_row4_col1" class="data row4 col1" >0.102</td>
#       <td id="T_70e14_row4_col2" class="data row4 col2" >0.00%</td>
#     </tr>
#     <tr>
#       <th id="T_70e14_level0_row5" class="row_heading level0 row5" >Rate at Prior Equilibrium</th>
#       <td id="T_70e14_row5_col0" class="data row5 col0" >0.114</td>
#       <td id="T_70e14_row5_col1" class="data row5 col1" >0.115</td>
#       <td id="T_70e14_row5_col2" class="data row5 col2" >0.01%</td>
#     </tr>
#   </tbody>
# </table>

# %% [markdown]
# ### Current Debt Ceiling

# %%
debt_ceiling = int(stats.at['Total Non-Idle Allocation', 'Current'] + idle_df['Maker Allocation'].sum())
print(f'The current debt ceiling is: ${debt_ceiling}')
# Out:
# The current debt ceiling is: $450077169
